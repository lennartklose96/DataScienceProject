# %%
#import sys
#!{sys.executable} -m pip install plotly      #falls man noch was installieren muss, geht das hiermit recht leicht

# %%
import requests
import urllib.parse as up
import pandas
from pandas import json_normalize
import json
base = "https://rest.arbeitsagentur.de/jobboerse/jobsuche-service/pc/v4/jobs"
query = {
    "angebotsart": "1",
    "wo": "Schleswig-Holstein",
    #"umkreis": "200",
    #"arbeitszeit": "ho;mj",  # Semikolon bleibt bewusst erhalten
    #"page": "5",
    "size": "250",
    #"pav": "false",
}
# safe=';' sorgt dafür, dass das Semikolon nicht encodiert wird, falls die API es so erwartet
url = f"{base}?{up.urlencode(query, safe=';')}"

headers = {
    "X-API-Key": "jobboerse-jobsuche",
    #"Accept": "application/json",
    #"User-Agent": "Mozilla/5.0",
}

r = requests.get(url, headers=headers, timeout=30)
print("URL:", r.url)
print("Status:", r.status_code, r.reason)
print("CT:", r.headers.get("content-type"))
data= r.json()
# Out:
# URL: https://rest.arbeitsagentur.de/jobboerse/jobsuche-service/pc/v4/jobs?angebotsart=1&wo=Schleswig-Holstein&size=250
# Status: 200 OK
# CT: application/json;charset=UTF-8

# %%
print(data.keys())
# Out:
# dict_keys(['stellenangebote', 'maxErgebnisse', 'page', 'size', 'woOutput', 'facetten'])

# %%
facetten=data["facetten"] #alle möglichen Eigenschaften inklusive der dort vorhanden Daten denke ich mal für Angebotsart 1
#facetten                  #aus manchen Eigenschaften werde ich aber noch nicht so richtig schlau, da keine Einheiten gegeben sind

# %%
#print(data.get("stellenangebote"))

# %%
jobs=data["stellenangebote"]
#jobs

# %%
df_job_SH = json_normalize(jobs)
#df_job_SH

# %%
df_job_SH = df_job_SH[["beruf",	"titel",	"refnr",	"arbeitgeber",	"aktuelleVeroeffentlichungsdatum",	"modifikationsTimestamp",	"eintrittsdatum",	"arbeitsort.plz",	"arbeitsort.ort",	"arbeitsort.strasse",	"arbeitsort.region",	"arbeitsort.land",	"arbeitsort.koordinaten.lat",	"arbeitsort.koordinaten.lon",	"arbeitsort.ortsteil",	"externeUrl"]]
#df_job_SH

# %%
all_jobs = []

for page in range(1, 3):  # immer Seite 1 als Minimum haben - geht aber auch Seite 41 bis 81
    query["page"] = page   #oben habe ich size 250 gesetzt, daher kriegt man 250 x Seitenanzahl an Ergebnissen
    url = f"{base}?{up.urlencode(query, safe=';')}"  #250 x 40 = 10000
    
    r = requests.get(url, headers=headers, timeout=30)
    data = r.json()
    
    all_jobs.extend(data["stellenangebote"])

df_job_SH = json_normalize(all_jobs) #erzeugt die Spaltenform die man unten sehen kann
df_job_SH = df_job_SH[["beruf",	#alle Spalten die man in der Rückgabe haben will - habe zB die Hashs der spezifischen Personen 
         "titel",	#mal rausgenommen, da wir damit denke eh nichts machen werden
         #"refnr",	
         #"arbeitgeber",	
         #"aktuelleVeroeffentlichungsdatum",	
         #"modifikationsTimestamp",	
         #"eintrittsdatum",	
         #"arbeitsort.plz",	
         #"arbeitsort.ort",	
         #"arbeitsort.strasse",	
         #"arbeitsort.region",	
         #"arbeitsort.land",	
         #"arbeitsort.koordinaten.lat",	
         #"arbeitsort.koordinaten.lon",	
         #"arbeitsort.ortsteil",	
         #"externeUrl"
        ]]
df_job_SH
# Out:
#                                                  beruf  \
# 0                         Leiter/in - Maschinenanlagen
# 1    Industriemechaniker/in - Maschinen- und System...
# 2                        Ingenieur/in - Elektrotechnik
# 3                            Fachberater/in - Vertrieb
# 4                                     Projektleiter/in
# ..                                                 ...
# 495                                   Reifenmonteur/in
# 496   Konstruktionsmechaniker/in - Feinblechbautechnik
# 497                    Lager- und Transportarbeiter/in
# 498                              Helfer/in - Metallbau
# 499                   Helfer/in - Malerei, Lackiererei
#
#                                                  titel
# 0    Seefahrender Ingenieur Führungs- und Waffenein...
# 1    Industriemechaniker Maschinen- und Systemtechn...
# 2         PLC Development and Support Engineer (f/m/d)
# 3    Vertrieb Fachbereich Bauelemente (m/w/d),  Lübeck
# 4                   Projektleiter (m/w/d) Photovoltaik
# ..                                                 ...
# 495  Lagermitarbeiter im Wareneingang (m/w/d) ab 14...
# 496  Konstruktionsmechaniker - Feinblechbautechnik ...
# 497    Lagermitarbeiter  (m/w/d) ab 14,96€ Stundenlohn
# 498   Helfer - Metallbau (m/w/d) ab 15,29€ pro Stunde
# 499  Helfer - Malerei, Lackiererei (m/w/d) Vollzeit...
#
# [500 rows x 2 columns]

# %%
df_job_SH.to_csv("jobs_SH_500.csv", index=False)

# %%
base = "https://rest.arbeitsagentur.de/jobboerse/bewerbersuche-service/pc/v1/bewerber"
query = {
    #"angebotsart": "",
    #"was": "",
    #"ausbildungsart": "",
    "wo": "Schleswig-Holstein",  
    #"umkreis": "",
    #"angebotsart": "",
    #"arbeitszeit": "",
    #"berufserfahrung": "",
    #"vertragsart": "",
    #"page": "",  #Seiten beginnen bei 0
    "size": "250",
    
}
# safe=';' sorgt dafür, dass das Semikolon nicht encodiert wird, falls die API es so erwartet
url = f"{base}?{up.urlencode(query, safe=';')}"

headers = {
    "X-API-Key": "jobboerse-bewerbersuche-ui",
    #"Accept": "application/json",
    #"User-Agent": "Mozilla/5.0",
}

r = requests.get(url, headers=headers, timeout=30)
print("URL:", r.url)
print("Status:", r.status_code, r.reason)
print("CT:", r.headers.get("content-type"))
data= r.json()
# Out:
# URL: https://rest.arbeitsagentur.de/jobboerse/bewerbersuche-service/pc/v1/bewerber?wo=Schleswig-Holstein&size=250
# Status: 200 OK
# CT: application/json

# %%
print(data.keys())
# Out:
# dict_keys(['bewerber', 'maxErgebnisse', 'page', 'size', 'woOutput', 'facetten'])

# %%
bewerber=data["bewerber"]
bewerber
# Out:
# [{'refnr': '10005-135012005101862978-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T06:33:30.934',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['TEILZEIT'],
#   'berufe': ['Pförtner/in'],
#   'erfahrung': {'gesamterfahrung': 'P13Y9M13D'},
#   'letzteTaetigkeit': {'jahr': '2019',
#    'bezeichnung': 'Helfer/in - Reinigung',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Eutin',
#    'plz': '23701',
#    'umkreis': '20',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10005-115171997032452442-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T15:40:36.544',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT', 'TEILZEIT'],
#   'berufe': ['Helfer/in - Büro, Verwaltung',
#    'Kaufmann/-frau - Groß- und Außenhandel (Außenhandel)'],
#   'ausbildungen': [{'jahr': 1990,
#     'art': 'Kaufmann/-frau - Groß- und Außenhandel (Außenhandel)'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Handel',
#      'erfahrung': 'P1Y'}],
#    'gesamterfahrung': 'P8Y6M24D'},
#   'letzteTaetigkeit': {'jahr': '2015',
#    'bezeichnung': 'Helfer/in - Küche',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Pinneberg',
#    'plz': '25421',
#    'umkreis': '20',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': True},
#  {'refnr': '10005-115151997020788885-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T10:32:20.314',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT',
#    'TEILZEIT',
#    'SCHICHT_NACHTARBEIT_WOCHENENDE'],
#   'berufe': ['Helfer/in - Metallbearbeitung'],
#   'ausbildungen': [{'jahr': 1997, 'art': 'Industriemechaniker/in'}],
#   'erfahrung': {'gesamterfahrung': 'P5Y3M17D'},
#   'letzteTaetigkeit': {'jahr': '2013',
#    'bezeichnung': 'Industriemechaniker/in',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': True,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Hemdingen',
#    'plz': '25485',
#    'umkreis': '20',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10005-115011999100170814-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T10:22:01.458',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT',
#    'TEILZEIT',
#    'SCHICHT_NACHTARBEIT_WOCHENENDE'],
#   'berufe': ['Gabelstaplerfahrer/in',
#    'Helfer/in - Verkauf',
#    'Tontechniker/in'],
#   'expertenKenntnisse': ['Beladen, Entladen'],
#   'ausbildungen': [{'jahr': 2001, 'art': 'Tischler/in'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Verkauf (ohne Produktspezialisierung)',
#      'erfahrung': 'P6M'}],
#    'gesamterfahrung': 'P1Y11M2D'},
#   'letzteTaetigkeit': {'jahr': '2013',
#    'bezeichnung': 'Helfer/in - Holz, Flechtwaren',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': True,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Elmshorn',
#    'plz': '25337',
#    'umkreis': '25',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205658345-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T17:14:34.489',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Helfer/in - Lagerwirtschaft, Transport',
#    'Gabelstaplerfahrer/in'],
#   'erfahrung': {'gesamterfahrung': 'P9Y7M'},
#   'letzteTaetigkeit': {'jahr': '2016',
#    'bezeichnung': 'Helfer/in - Tiefbau',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Kiel',
#    'plz': '24109',
#    'umkreis': '30',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205658099-B',
#   'verfuegbarkeitVon': '2026-06-01',
#   'aktualisierungsdatum': '2026-02-27T15:22:56.168',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['TEILZEIT'],
#   'berufe': ['ERP-Berater/in - ERP-Consultant'],
#   'ausbildungen': [{'jahr': 2009, 'art': 'Diplom-Kaufmann/-frau'},
#    {'jahr': 2003, 'art': 'Allgemeine Hochschulreife'}],
#   'erfahrung': {'gesamterfahrung': 'P8Y11M26D'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Produktmanager/in',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': True,
#   'lokation': {'ort': 'Flensburg',
#    'plz': '24943',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205657581-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T13:42:17.134',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT',
#    'TEILZEIT',
#    'SCHICHT_NACHTARBEIT_WOCHENENDE'],
#   'berufe': ['Textilreiniger/in'],
#   'ausbildungen': [{'jahr': 2014,
#     'art': 'Bachelor of Arts - Rechtswissenschaft'},
#    {'jahr': 2010, 'art': 'Allgemeine Hochschulreife'}],
#   'erfahrung': {'gesamterfahrung': 'P5Y'},
#   'letzteTaetigkeit': {'jahr': '2019',
#    'bezeichnung': 'Polizeivollzugsbeamter/-beamtin (höherer Dienst)',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Kiel',
#    'plz': '24109',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205656874-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T12:35:33.574',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['TEILZEIT'],
#   'berufe': ['Verkäufer/in'],
#   'ausbildungen': [{'jahr': 2020, 'art': 'Fachkraft - Gastronomie'},
#    {'jahr': 2018, 'art': 'Hauptschulabschluss'}],
#   'erfahrung': {'gesamterfahrung': 'P3Y5M26D'},
#   'letzteTaetigkeit': {'bezeichnung': 'Verkäufer/in', 'aktuell': True},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Neumünster, Holstein',
#    'plz': '24536',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205656122-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T11:59:23.478',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Vorarbeiter/in - Reinigung', 'Disponent/in - Güterverkehr'],
#   'ausbildungen': [{'jahr': 1999, 'art': 'Allgemeine Hochschulreife'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Reinigung',
#      'erfahrung': 'P2Y1M26D'},
#     {'berufsfeld': 'Kaufleute - Verkehr und Logistik', 'erfahrung': 'P12Y'}],
#    'gesamterfahrung': 'P14Y1M26D'},
#   'letzteTaetigkeit': {'bezeichnung': 'Kaufmann/-frau - Einzelhandel (Kraftfahrzeuge, Teile und Zubehör)',
#    'aktuell': True},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Reinfeld (Holstein)',
#    'plz': '23858',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205655919-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T12:20:56.804',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Montierer/in'],
#   'expertenKenntnisse': ['Kassieren'],
#   'ausbildungen': [{'jahr': 1993, 'art': 'Friseur/in'},
#    {'jahr': 1990, 'art': 'Hauptschulabschluss'}],
#   'erfahrung': {'gesamterfahrung': 'P32Y6M'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Helfer/in - Metallbau',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': True,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Lübeck',
#    'plz': '23556',
#    'umkreis': '20',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205655851-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T12:04:17.723',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['TEILZEIT'],
#   'berufe': ['Bankkaufmann/-frau',
#    'Rechtsanwalts- und Notarfachangestellte/r',
#    'Kaufmännische Fachkraft'],
#   'ausbildungen': [{'jahr': 1986,
#     'art': 'Rechtsanwalts- und Notarfachangestellte/r'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Rechtsberatung, -sprechung und -ordnung',
#      'erfahrung': 'P4Y9M'},
#     {'berufsfeld': 'Versicherungs- und Finanzdienstleistungen',
#      'erfahrung': 'P34Y10M26D'}],
#    'gesamterfahrung': 'P39Y7M26D'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Bankkaufmann/-frau',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Oststeinbek',
#    'plz': '22113',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205655846-B',
#   'verfuegbarkeitVon': '2026-02-28',
#   'aktualisierungsdatum': '2026-02-27T12:05:29.05',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT', 'TEILZEIT'],
#   'berufe': ['Sozialpädagogische/r Assistent/in / Kinderpfleger/in'],
#   'ausbildungen': [{'jahr': 2025,
#     'art': 'Sozialpädagogische/r Assistent/in / Kinderpfleger/in'},
#    {'jahr': 2022, 'art': 'Mittlere Reife / Mittlerer Bildungsabschluss'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Erziehung, Sozialarbeit, Heilerziehungspflege',
#      'erfahrung': 'P5M'}],
#    'gesamterfahrung': 'P5M'},
#   'letzteTaetigkeit': {'jahr': '2025',
#    'bezeichnung': 'Sozialpädagogische/r Assistent/in / Kinderpfleger/in',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Lübeck',
#    'plz': '23570',
#    'umkreis': '20',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205655831-B',
#   'verfuegbarkeitVon': '2026-03-07',
#   'aktualisierungsdatum': '2026-02-27T12:01:53.533',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Vertriebsassistent/in'],
#   'expertenKenntnisse': ['E-Mail-Programm Outlook (MS Office)',
#    'Textverarbeitung Word (MS Office)',
#    'Korrespondenz',
#    'Büromaterialverwaltung',
#    'Postbearbeitung'],
#   'ausbildungen': [{'jahr': 2018, 'art': 'Fachhochschulreife'}],
#   'erfahrung': {'gesamterfahrung': 'P3Y2M24D'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Studiengangkoordinator/in',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': True,
#   'lokation': {'ort': 'Hochdonn',
#    'plz': '25712',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205655798-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T11:48:59.539',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['TEILZEIT'],
#   'berufe': ['Museumsaufseher/in'],
#   'erfahrung': {'gesamterfahrung': 'P34Y1M19D'},
#   'letzteTaetigkeit': {'jahr': '2025',
#    'bezeichnung': 'Versicherungskaufmann/-frau',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Geesthacht',
#    'plz': '21502',
#    'umkreis': '30',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205655583-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T11:44:51.227',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['TEILZEIT', 'MINIJOB'],
#   'berufe': ['Pförtner/in'],
#   'expertenKenntnisse': ['Erziehung',
#    'Kinder (Betreuung etc.)',
#    'Elternarbeit',
#    'Freizeitgestaltung',
#    'Sozialpädagogik'],
#   'ausbildungen': [{'jahr': 1989, 'art': 'Erzieher/in'},
#    {'jahr': 1984, 'art': 'Mittlere Reife / Mittlerer Bildungsabschluss'}],
#   'erfahrung': {'gesamterfahrung': 'P20Y7M'},
#   'letzteTaetigkeit': {'jahr': '2023',
#    'bezeichnung': 'Sozialarbeiter/in / Sozialpädagoge/-pädagogin',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Olderup',
#    'plz': '25860',
#    'umkreis': '15',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205655527-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T11:55:36.649',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Helfer/in - Verkauf'],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Verkauf (ohne Produktspezialisierung)',
#      'erfahrung': 'P1Y4M26D'}],
#    'gesamterfahrung': 'P1Y4M26D'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Helfer/in - Verkauf',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Lübeck',
#    'plz': '23556',
#    'umkreis': '10',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205655350-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T11:37:23.52',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT',
#    'TEILZEIT',
#    'SCHICHT_NACHTARBEIT_WOCHENENDE'],
#   'berufe': ['Helfer/in - Reinigung'],
#   'ausbildungen': [{'jahr': 2001,
#     'art': 'Bachelor of Arts - Musik (Dirigieren)'},
#    {'jahr': 1996, 'art': 'Bachelor of Arts - Musik'},
#    {'jahr': 1991, 'art': 'Mittlere Reife / Mittlerer Bildungsabschluss'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Reinigung',
#      'erfahrung': 'P8M2D'}],
#    'gesamterfahrung': 'P27Y1M21D'},
#   'letzteTaetigkeit': {'bezeichnung': 'Musiklehrer/in', 'aktuell': True},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Lübeck',
#    'plz': '23569',
#    'umkreis': '25',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205654642-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T12:03:39.124',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['TEILZEIT',
#    'SCHICHT_NACHTARBEIT_WOCHENENDE',
#    'MINIJOB'],
#   'berufe': ['Helfer/in - Verkauf',
#    'Servicekraft - Gastronomie und Gastgewerbe',
#    'Helfer/in - Lagerwirtschaft, Transport'],
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Flensburg',
#    'plz': '24939',
#    'umkreis': '10',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205654430-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T11:12:55.804',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Pförtner/in'],
#   'ausbildungen': [{'jahr': 1990, 'art': 'Werkzeugmacher/in'}],
#   'erfahrung': {'gesamterfahrung': 'P7Y1M2D'},
#   'letzteTaetigkeit': {'jahr': '2025',
#    'bezeichnung': 'Pharmakant/in',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Oldenburg in Holstein',
#    'plz': '23758',
#    'umkreis': '15',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205653161-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T10:54:34.766',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Helfer/in - Verkauf'],
#   'expertenKenntnisse': ['Kassieren',
#    'Warenauszeichnung',
#    'Regalauffüllen',
#    'Warenpräsentation'],
#   'ausbildungen': [{'jahr': 2021, 'art': 'Allgemeine Hochschulreife'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Verkauf (ohne Produktspezialisierung)',
#      'erfahrung': 'P3Y3M26D'}],
#    'gesamterfahrung': 'P3Y3M26D'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Verkäufer/in',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': True,
#   'lokation': {'ort': 'Engelbrechtsche Wildnis',
#    'plz': '25348',
#    'umkreis': '30',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205652675-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T10:31:12.452',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['TEILZEIT'],
#   'berufe': ['Helfer/in - Verkauf'],
#   'ausbildungen': [{'jahr': 2015, 'art': 'Friseur/in'},
#    {'jahr': 2012, 'art': 'Mittlere Reife / Mittlerer Bildungsabschluss'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Verkauf (ohne Produktspezialisierung)',
#      'erfahrung': 'P11M'}],
#    'gesamterfahrung': 'P10Y27D'},
#   'letzteTaetigkeit': {'jahr': '2025',
#    'bezeichnung': 'Helfer/in - Verkauf',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Elmshorn',
#    'plz': '25335',
#    'umkreis': '30',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205652413-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T10:27:08.228',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Helfer/in - Lagerwirtschaft, Transport'],
#   'erfahrung': {'gesamterfahrung': 'P1Y2M6D'},
#   'letzteTaetigkeit': {'jahr': '2024',
#    'bezeichnung': 'Pflegeassistent/in',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': True,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Lübeck',
#    'plz': '23552',
#    'umkreis': '30',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205652295-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T10:19:23.752',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['TEILZEIT'],
#   'berufe': ['Helfer/in - Verkauf'],
#   'ausbildungen': [{'jahr': 2019, 'art': 'Hauptschulabschluss'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Verkauf (ohne Produktspezialisierung)',
#      'erfahrung': 'P4M16D'}],
#    'gesamterfahrung': 'P4M16D'},
#   'letzteTaetigkeit': {'jahr': '2020',
#    'bezeichnung': 'Helfer/in - Verkauf',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Uetersen',
#    'plz': '25436',
#    'umkreis': '30',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205652225-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T11:24:25.02',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT', 'TEILZEIT'],
#   'berufe': ['Tierphysiotherapeut/in', 'Helfer/in - Büro, Verwaltung'],
#   'ausbildungen': [{'jahr': 2024, 'art': 'Tierphysiotherapeut/in'},
#    {'jahr': 2020, 'art': 'Allgemeine Hochschulreife'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Tiermedizin und Tierheilkunde',
#      'erfahrung': 'P1Y5M17D'}],
#    'gesamterfahrung': 'P1Y9M2D'},
#   'letzteTaetigkeit': {'bezeichnung': 'Helfer/in - Verkauf', 'aktuell': True},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Lübeck',
#    'plz': '23558',
#    'umkreis': '20',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205652168-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T11:06:44.606',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT',
#    'TEILZEIT',
#    'SCHICHT_NACHTARBEIT_WOCHENENDE'],
#   'berufe': ['Helfer/in - Verkauf'],
#   'expertenKenntnisse': ['Verkauf', 'Abrechnung', 'Regalauffüllen'],
#   'ausbildungen': [{'jahr': 2012,
#     'art': 'Bachelor of Arts - Allgemeine Finanzverwaltung'},
#    {'jahr': 2004, 'art': 'Allgemeine Hochschulreife'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Verkauf (ohne Produktspezialisierung)',
#      'erfahrung': 'P2Y11M3D'}],
#    'gesamterfahrung': 'P6Y11M3D'},
#   'letzteTaetigkeit': {'jahr': '2023',
#    'bezeichnung': 'Verkäufer/in',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Elmshorn',
#    'plz': '25335',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205651971-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T10:44:19.306',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT', 'TEILZEIT'],
#   'berufe': ['Helfer/in - Verkauf'],
#   'ausbildungen': [{'jahr': 2023, 'art': 'Hauptschulabschluss'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Verkauf (ohne Produktspezialisierung)',
#      'erfahrung': 'P22D'}],
#    'gesamterfahrung': 'P22D'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Helfer/in - Verkauf',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Wulfsmoor',
#    'plz': '25563',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205651423-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T11:45:41.599',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT', 'TEILZEIT'],
#   'berufe': ['Helfer/in - Lebensmittelherstellung'],
#   'ausbildungen': [{'jahr': 1987,
#     'art': 'Bachelor - Lehramt an Haupt-, Real- und Gesamtschulen'},
#    {'jahr': 1982, 'art': 'Allgemeine Hochschulreife'}],
#   'erfahrung': {'gesamterfahrung': 'P37Y5M'},
#   'letzteTaetigkeit': {'jahr': '2024',
#    'bezeichnung': 'Lehrer/in (Uni) - Gesamtschulen',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Lübeck',
#    'plz': '23556',
#    'umkreis': '20',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205651358-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T09:54:38.261',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['TEILZEIT'],
#   'berufe': ['Helfer/in - Verkauf'],
#   'ausbildungen': [{'jahr': 2025,
#     'art': 'Bachelor of Science - Angewandte Pharmazie - Applied Pharmacy'}],
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Schleswig',
#    'plz': '24837',
#    'umkreis': '5',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205651077-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T09:47:24.168',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Volkswirt/in', 'Helfer/in - Verkauf'],
#   'ausbildungen': [{'jahr': 2025,
#     'art': 'Master of Science - Volkswirtschaftslehre'},
#    {'jahr': 2020, 'art': 'Bachelor of Science - Sozioökonomik'},
#    {'jahr': 2017, 'art': 'Allgemeine Hochschulreife'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Verkauf (ohne Produktspezialisierung)',
#      'erfahrung': 'P3Y8M16D'}],
#    'gesamterfahrung': 'P5Y11M10D'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Projektassistent/in',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Kiel',
#    'plz': '24106',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205651042-B',
#   'verfuegbarkeitVon': '2026-06-18',
#   'aktualisierungsdatum': '2026-02-27T10:22:10.682',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['TEILZEIT'],
#   'berufe': ['Facharzt/-ärztin - Haut- und Geschlechtskrankheiten'],
#   'ausbildungen': [{'jahr': 2013, 'art': 'Staatsexamen - Humanmedizin'},
#    {'jahr': 2006, 'art': 'Allgemeine Hochschulreife'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Human- und Zahnmedizin',
#      'erfahrung': 'P12Y6M26D'}],
#    'gesamterfahrung': 'P12Y6M26D'},
#   'letzteTaetigkeit': {'bezeichnung': 'Facharzt/-ärztin - Haut- und Geschlechtskrankheiten',
#    'aktuell': True},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Lübeck',
#    'plz': '23568',
#    'umkreis': '8',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205650930-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T10:15:04.748',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['TEILZEIT'],
#   'berufe': ['Helfer/in - Büro, Verwaltung',
#    'Empfangskraft',
#    'Büroassistent/in'],
#   'ausbildungen': [{'jahr': 1999,
#     'art': 'Pharmazeutisch-technische/r Assistent/in'},
#    {'jahr': 1997, 'art': 'Pharmazeutisch-kaufmännische/r Angestellte/r'},
#    {'jahr': 1994, 'art': 'Mittlere Reife / Mittlerer Bildungsabschluss'}],
#   'erfahrung': {'gesamterfahrung': 'P6Y'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Pharmazeutisch-technische/r Assistent/in',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Wacken',
#    'plz': '25596',
#    'umkreis': '20',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205650619-B',
#   'verfuegbarkeitVon': '2027-10-01',
#   'aktualisierungsdatum': '2026-02-27T09:38:41.217',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT', 'TEILZEIT'],
#   'berufe': ['Helfer/in - Hochbau'],
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Kiel',
#    'plz': '24159',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205650610-B',
#   'verfuegbarkeitVon': '2026-04-01',
#   'aktualisierungsdatum': '2026-02-27T09:37:15.367',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['TEILZEIT'],
#   'berufe': ['Qualitätsbeauftragte/r - Gesundheits-/Sozialwesen',
#    'Qualitätsmanager/in',
#    'Patientenmanager/in'],
#   'expertenKenntnisse': ['E-Mail-Programm Outlook (MS Office)'],
#   'ausbildungen': [{'jahr': 2018,
#     'art': 'Bachelor of Science - Angewandte Gesundheitswissenschaft'},
#    {'jahr': 2010, 'art': 'Medizinische/r Fachangestellte/r'},
#    {'jahr': 2008, 'art': 'Allgemeine Hochschulreife'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Arzt- und Praxishilfe',
#      'erfahrung': 'P4Y7M27D'}],
#    'gesamterfahrung': 'P12Y4M23D'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Projektleiter/in',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Ellerbek, Kreis Pinneberg',
#    'plz': '25474',
#    'umkreis': '30',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205650478-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T09:32:13.11',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Pförtner/in'],
#   'ausbildungen': [{'jahr': 1980, 'art': 'Hauptschulabschluss'}],
#   'erfahrung': {'gesamterfahrung': 'P19Y'},
#   'letzteTaetigkeit': {'jahr': '1999',
#    'bezeichnung': 'Elektroinstallateur/in',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Barsbüttel',
#    'plz': '22885',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205650457-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T09:32:27.701',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Servicekraft - Gastronomie und Gastgewerbe'],
#   'ausbildungen': [{'jahr': 2024, 'art': 'Fachhochschulreife'},
#    {'jahr': 2021, 'art': 'Mittlere Reife / Mittlerer Bildungsabschluss'},
#    {'jahr': 2019, 'art': 'Hauptschulabschluss'},
#    {'jahr': 2018, 'art': 'Hauptschulabschluss'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Gastronomie',
#      'erfahrung': 'P5M20D'}],
#    'gesamterfahrung': 'P5M20D'},
#   'letzteTaetigkeit': {'jahr': '2025',
#    'bezeichnung': 'Servicekraft - Gastronomie und Gastgewerbe',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Lübeck',
#    'plz': '23569',
#    'umkreis': '25',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205650248-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T09:31:01.384',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Helfer/in - Verkauf'],
#   'ausbildungen': [{'jahr': 2023, 'art': 'Allgemeine Hochschulreife'}],
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Norderstedt',
#    'plz': '22846',
#    'umkreis': '10',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205649674-B',
#   'verfuegbarkeitVon': '2026-06-01',
#   'aktualisierungsdatum': '2026-02-27T09:33:44.323',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Betriebsschlosser/in'],
#   'ausbildungen': [{'jahr': 1985, 'art': 'Schlosser/in'},
#    {'jahr': 1982, 'art': 'Hauptschulabschluss'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Maschinenbau- und Betriebstechnik',
#      'erfahrung': 'P10Y7M26D'}],
#    'gesamterfahrung': 'P10Y7M26D'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Betriebsschlosser/in',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Stockelsdorf',
#    'plz': '23617',
#    'umkreis': '10',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205649571-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T09:13:50.128',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT',
#    'TEILZEIT',
#    'SCHICHT_NACHTARBEIT_WOCHENENDE'],
#   'berufe': ['Helfer/in - Verkauf', 'Helfer/in - Lagerwirtschaft, Transport'],
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Norderstedt',
#    'plz': '22846',
#    'umkreis': '20',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205649383-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T09:10:12.903',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Helfer/in - Büro, Verwaltung'],
#   'erfahrung': {'gesamterfahrung': 'P21Y6M15D'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Pflegedienstleiter/in',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'St. Michaelisdonn',
#    'plz': '25693',
#    'umkreis': '30',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205649227-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T09:02:51.312',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Helfer/in - Maschinenbau, Betriebstechnik',
#    'Hausmeister/in',
#    'Maschinen- und Anlagenführer/in (ohne Angabe des Schwerpunkts)'],
#   'erfahrung': {'gesamterfahrung': 'P3Y3M26D'},
#   'letzteTaetigkeit': {'bezeichnung': 'Schleifer/in', 'aktuell': True},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Heide, Holstein',
#    'plz': '25746',
#    'umkreis': '30',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205649221-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T11:06:35.813',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT',
#    'TEILZEIT',
#    'SCHICHT_NACHTARBEIT_WOCHENENDE'],
#   'berufe': ['Helfer/in - Landwirtschaft'],
#   'expertenKenntnisse': ['Handwerkliche Kenntnisse', 'Lagerarbeit'],
#   'ausbildungen': [{'jahr': 2019, 'art': 'Bäcker/in'}],
#   'erfahrung': {'gesamterfahrung': 'P2Y9M10D'},
#   'letzteTaetigkeit': {'jahr': '2023',
#    'bezeichnung': 'Helfer/in - Lagerwirtschaft, Transport',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Glückstadt',
#    'plz': '25348',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205649046-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T10:13:34.54',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Sozialarbeiter/in / Sozialpädagoge/-pädagogin'],
#   'ausbildungen': [{'jahr': 2017, 'art': 'Fachhochschulreife'},
#    {'jahr': 2017, 'art': 'Sozialpädagogische/r Assistent/in'}],
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Mölln, Kreis Herzogtum Lauenburg',
#    'plz': '23879',
#    'umkreis': '30',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205648928-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T09:23:52.677',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Helfer/in - Küche'],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Speisenzubereitung',
#      'erfahrung': 'P1Y6M23D'}],
#    'gesamterfahrung': 'P1Y6M23D'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Helfer/in - Küche',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Lübeck',
#    'plz': '23566',
#    'umkreis': '10',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205648762-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T08:49:04.653',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT', 'TEILZEIT'],
#   'berufe': ['Helfer/in - Feinmechanik, Werkzeugbau'],
#   'ausbildungen': [{'jahr': 2024, 'art': 'Hauptschulabschluss'}],
#   'erfahrung': {'gesamterfahrung': 'P5M14D'},
#   'letzteTaetigkeit': {'jahr': '2024',
#    'bezeichnung': 'Helfer/in - Kurier-, Zustell- und Postdienstleistungen',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Uetersen',
#    'plz': '25436',
#    'umkreis': '30',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205648529-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T09:26:14.019',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Koch/Köchin'],
#   'expertenKenntnisse': ['Lebensmittelhygiene',
#    'Gemüse-, Salatzubereitung',
#    'Arbeitsvorbereitung',
#    'Beilagenzubereitung',
#    'Speisen zubereiten und anrichten'],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Speisenzubereitung',
#      'erfahrung': 'P10Y5M4D'}],
#    'gesamterfahrung': 'P10Y5M4D'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Koch/Köchin',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Lübeck',
#    'plz': '23558',
#    'umkreis': '30',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205648449-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T08:42:41.916',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT',
#    'TEILZEIT',
#    'SCHICHT_NACHTARBEIT_WOCHENENDE'],
#   'berufe': ['Busfahrer/in'],
#   'ausbildungen': [{'jahr': 1990, 'art': 'Hauptschulabschluss'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Fahrzeugführung im Straßenverkehr',
#      'erfahrung': 'P11Y2M6D'}],
#    'gesamterfahrung': 'P31Y18D'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Hausmeister/in',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Bargenstedt',
#    'plz': '25704',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205647376-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T08:10:45.32',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT', 'TEILZEIT'],
#   'berufe': ['Elektromechaniker/in'],
#   'ausbildungen': [{'jahr': 2008, 'art': 'Tischler/in'},
#    {'jahr': 2005, 'art': 'Hauptschulabschluss'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Elektrotechnik',
#      'erfahrung': 'P5M23D'}],
#    'gesamterfahrung': 'P1Y2M1D'},
#   'letzteTaetigkeit': {'jahr': '2025',
#    'bezeichnung': 'Hausmeister/in',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Elmshorn',
#    'plz': '25336',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205647362-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T08:10:01.825',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT', 'TEILZEIT'],
#   'berufe': ['Helfer/in - Verkauf'],
#   'ausbildungen': [{'jahr': 1994, 'art': 'Hauptschulabschluss'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Verkauf (ohne Produktspezialisierung)',
#      'erfahrung': 'P1Y'}],
#    'gesamterfahrung': 'P2Y6M3D'},
#   'letzteTaetigkeit': {'bezeichnung': 'Gebäudereiniger/in', 'aktuell': True},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Elmshorn',
#    'plz': '25336',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205647359-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T08:55:59.172',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Techniker/in - Kraftfahrzeugtechnik/Bachelor Professional in Technik'],
#   'ausbildungen': [{'jahr': 2016,
#     'art': 'Bachelor of Science - Management und Technik'},
#    {'jahr': 2010, 'art': 'Fachgebundene Hochschulreife'},
#    {'jahr': 2009,
#     'art': 'Kaufmännische/r Assistent/in - Datenverarbeitung/Informationsverarbeitung'}],
#   'erfahrung': {'gesamterfahrung': 'P5Y1M'},
#   'letzteTaetigkeit': {'jahr': '2025',
#    'bezeichnung': 'Ingenieur/in - Versorgungstechnik',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Hammoor bei Ahrensburg',
#    'plz': '22941',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205647296-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T08:30:00.488',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Museumsaufseher/in', 'Berufskraftfahrer/in'],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Fahrzeugführung im Straßenverkehr',
#      'erfahrung': 'P9M23D'}],
#    'gesamterfahrung': 'P9M23D'},
#   'letzteTaetigkeit': {'jahr': '2025',
#    'bezeichnung': 'Berufskraftfahrer/in',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Kappeln, Schlei',
#    'plz': '24376',
#    'umkreis': '30',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205647030-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T07:55:21.766',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT', 'TEILZEIT'],
#   'berufe': ['Lehrer/in - Grundschulen'],
#   'ausbildungen': [{'jahr': 1994, 'art': 'Sparkassenbetriebswirt/in'},
#    {'jahr': 1991, 'art': 'Bankkaufmann/-frau'},
#    {'jahr': 1988, 'art': 'Allgemeine Hochschulreife'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Lehrtätigkeit an allgemeinbildenden Schulen',
#      'erfahrung': 'P8Y3M10D'}],
#    'gesamterfahrung': 'P16Y4M22D'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Lehrer/in - Grundschulen',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Bäk bei Ratzeburg',
#    'plz': '23909',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205646788-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T07:30:33.253',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Ambulante/r Pfleger/in'],
#   'erfahrung': {'gesamterfahrung': 'P7M21D'},
#   'letzteTaetigkeit': {'jahr': '2024',
#    'bezeichnung': 'Betreuungshelfer/in (Flüchtlingshilfe)',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Pinneberg',
#    'plz': '25421',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205646523-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T09:25:10.799',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Helfer/in - Klempnerei, Installation'],
#   'ausbildungen': [{'jahr': 2015, 'art': 'Hauptschulabschluss'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Klempnerei, Sanitär-, Heizungs- und Klimatechnik',
#      'erfahrung': 'P1Y4M26D'}],
#    'gesamterfahrung': 'P1Y4M26D'},
#   'letzteTaetigkeit': {'bezeichnung': 'Helfer/in - Klempnerei, Installation',
#    'aktuell': True},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Wedel',
#    'plz': '22880',
#    'umkreis': '30',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205646520-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T06:53:07.294',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Helfer/in - Verkauf'],
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Wedel',
#    'plz': '22880',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205646459-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T06:40:08.973',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Helfer/in - Verkauf'],
#   'ausbildungen': [{'jahr': 2025, 'art': 'Hauptschulabschluss'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Verkauf (ohne Produktspezialisierung)',
#      'erfahrung': 'P3M22D'}],
#    'gesamterfahrung': 'P3M22D'},
#   'letzteTaetigkeit': {'bezeichnung': 'Helfer/in - Verkauf', 'aktuell': True},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Schenefeld, Bz Hamburg',
#    'plz': '22869',
#    'umkreis': '20',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205645849-B',
#   'verfuegbarkeitVon': '2026-03-01',
#   'aktualisierungsdatum': '2026-02-27T09:28:12.744',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT', 'TEILZEIT'],
#   'berufe': ['Berechnungsingenieur/in'],
#   'ausbildungen': [{'jahr': 2020, 'art': 'Master of Science - Physik'},
#    {'jahr': 2012, 'art': 'Allgemeine Hochschulreife'}],
#   'erfahrung': {'gesamterfahrung': 'P3Y9M26D'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Softwareentwickler/in',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Neumünster, Holstein',
#    'plz': '24536',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205633067-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T10:48:00.12',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['TEILZEIT'],
#   'berufe': ['Pförtner/in'],
#   'erfahrung': {'gesamterfahrung': 'P2Y7M15D'},
#   'letzteTaetigkeit': {'jahr': '2025',
#    'bezeichnung': 'Betriebsleiter/in - technisch',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Goldelund',
#    'plz': '25862',
#    'umkreis': '20',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205602654-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T11:36:47.265',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Gebäudereiniger/in'],
#   'ausbildungen': [{'jahr': 2013, 'art': 'Bürokaufmann/-frau'},
#    {'jahr': 2010, 'art': 'Hauptschulabschluss'}],
#   'erfahrung': {'gesamterfahrung': 'P6Y4M26D'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Bürokaufmann/-frau',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Kasseedorf',
#    'plz': '23717',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205564914-B',
#   'verfuegbarkeitVon': '2026-02-27',
#   'aktualisierungsdatum': '2026-02-27T09:34:25.855',
#   'veroeffentlichungsdatum': '2026-02-27',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['TEILZEIT'],
#   'berufe': ['Gesundheits- und Krankenpfleger/in'],
#   'ausbildungen': [{'jahr': 2021, 'art': 'Gesundheits- und Krankenpfleger/in'},
#    {'jahr': 2018, 'art': 'Allgemeine Hochschulreife'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Krankenpflege, Rettungsdienst und Geburtshilfe',
#      'erfahrung': 'P4Y4M23D'}],
#    'gesamterfahrung': 'P4Y4M23D'},
# ...
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Altenpflege',
#      'erfahrung': 'P1Y'}],
#    'gesamterfahrung': 'P1Y'},
#   'letzteTaetigkeit': {'jahr': '2019',
#    'bezeichnung': 'Altenpflegehelfer/in',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Barmstedt',
#    'plz': '25355',
#    'umkreis': '20',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205630553-B',
#   'verfuegbarkeitVon': '2026-02-26',
#   'aktualisierungsdatum': '2026-02-26T09:07:41.512',
#   'veroeffentlichungsdatum': '2026-02-26',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT', 'TEILZEIT'],
#   'berufe': ['Softwareentwickler/in'],
#   'ausbildungen': [{'jahr': 2009, 'art': 'Allgemeine Hochschulreife'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Softwareentwicklung und Programmierung',
#      'erfahrung': 'P2Y4M27D'}],
#    'gesamterfahrung': 'P3Y8M29D'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Technische/r Assistent/in - medizinische Gerätetechnik',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Lübeck',
#    'plz': '23562',
#    'umkreis': '30',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205629992-B',
#   'verfuegbarkeitVon': '2026-02-26',
#   'aktualisierungsdatum': '2026-02-26T09:43:01.113',
#   'veroeffentlichungsdatum': '2026-02-26',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Berufskraftfahrer/in'],
#   'expertenKenntnisse': ['Beladen, Entladen',
#    'Fahrzeugführung',
#    'Speditions-, Lieferverkehr'],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Fahrzeugführung im Straßenverkehr',
#      'erfahrung': 'P4Y10M6D'}],
#    'gesamterfahrung': 'P4Y10M6D'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Berufskraftfahrer/in',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Neumünster, Holstein',
#    'plz': '24536',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205629874-B',
#   'verfuegbarkeitVon': '2026-02-26',
#   'aktualisierungsdatum': '2026-02-26T11:24:47.734',
#   'veroeffentlichungsdatum': '2026-02-26',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT', 'TEILZEIT'],
#   'berufe': ['Physiotherapeut/in'],
#   'ausbildungen': [{'jahr': 2023,
#     'art': 'Bachelor of Science - Agrarwissenschaft'},
#    {'jahr': 2015, 'art': 'Physiotherapeut/in (Ausbildung)'},
#    {'jahr': 2010, 'art': 'Allgemeine Hochschulreife'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Nichtärztliche Therapie und Heilkunde',
#      'erfahrung': 'P6Y10M29D'}],
#    'gesamterfahrung': 'P9Y2M9D'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Qualitätsmanager/in',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Bälau',
#    'plz': '23881',
#    'umkreis': '30',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205629758-B',
#   'verfuegbarkeitVon': '2026-02-26',
#   'aktualisierungsdatum': '2026-02-26T08:55:26.915',
#   'veroeffentlichungsdatum': '2026-02-26',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Helfer/in - Lagerwirtschaft, Transport',
#    'Helfer/in - Holz, Flechtwaren',
#    'Helfer/in - Lebensmittelherstellung'],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Lagerwirtschaft, Post und Zustellung, Güterumschlag',
#      'erfahrung': 'P1M26D'}],
#    'gesamterfahrung': 'P1M26D'},
#   'letzteTaetigkeit': {'bezeichnung': 'Helfer/in - Kurier-, Zustell- und Postdienstleistungen',
#    'aktuell': True},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Kaltenkirchen, Holstein',
#    'plz': '24568',
#    'umkreis': '25',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205629678-B',
#   'verfuegbarkeitVon': '2026-02-26',
#   'aktualisierungsdatum': '2026-02-26T09:52:36.518',
#   'veroeffentlichungsdatum': '2026-02-26',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Leiter/in - IT', 'IT-Projektkoordinator/in'],
#   'expertenKenntnisse': ['Arbeitsvorbereitung', 'Kalkulation'],
#   'ausbildungen': [{'jahr': 2008,
#     'art': 'Bachelor of Science - Informationstechnologie und Design'},
#    {'jahr': 2001, 'art': 'Fachgebundene Hochschulreife'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'IT-Netzwerktechnik, -Administration, -Organisation',
#      'erfahrung': 'P17Y10M26D'}],
#    'gesamterfahrung': 'P17Y10M26D'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Leiter/in - IT',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': True,
#   'hatAdresse': True,
#   'lokation': {'ort': 'Lübeck',
#    'plz': '23562',
#    'umkreis': '20',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': True},
#  {'refnr': '10000-1205629566-B',
#   'verfuegbarkeitVon': '2026-02-26',
#   'aktualisierungsdatum': '2026-02-26T08:40:14.82',
#   'veroeffentlichungsdatum': '2026-02-26',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Data Scientist'],
#   'ausbildungen': [{'jahr': 2025,
#     'art': 'Master of Science - Automatisierungstechnik'},
#    {'jahr': 2023,
#     'art': 'Bachelor of Science - Elektrotechnik/Informationstechnik'},
#    {'jahr': 2014, 'art': 'Steuerfachangestellte/r'},
#    {'jahr': 2011, 'art': 'Fachhochschulreife'}],
#   'erfahrung': {'gesamterfahrung': 'P1Y5M29D'},
#   'letzteTaetigkeit': {'jahr': '2015',
#    'bezeichnung': 'Steuerfachangestellte/r',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Preetz, Holstein',
#    'plz': '24211',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205629541-B',
#   'verfuegbarkeitVon': '2026-02-26',
#   'aktualisierungsdatum': '2026-02-26T08:39:25.871',
#   'veroeffentlichungsdatum': '2026-02-26',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Servicekraft - Gastronomie und Gastgewerbe'],
#   'ausbildungen': [{'jahr': 2000, 'art': 'Fachhochschulreife'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Gastronomie',
#      'erfahrung': 'P10Y'}],
#    'gesamterfahrung': 'P11Y5M15D'},
#   'letzteTaetigkeit': {'jahr': '2025',
#    'bezeichnung': 'Verkäufer/in - Nahrungsmittelhandwerk',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Niebüll',
#    'plz': '25899',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205629487-B',
#   'verfuegbarkeitVon': '2026-03-10',
#   'aktualisierungsdatum': '2026-02-26T09:28:05.238',
#   'veroeffentlichungsdatum': '2026-02-26',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Hausmeister/in'],
#   'ausbildungen': [{'jahr': 1985,
#     'art': 'Maler/in und Lackierer/in - Maler/in'},
#    {'jahr': 1982, 'art': 'Hauptschulabschluss'}],
#   'erfahrung': {'gesamterfahrung': 'P40Y6M25D'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Bodenleger/in',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Lübeck',
#    'plz': '23566',
#    'umkreis': '10',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205629473-B',
#   'verfuegbarkeitVon': '2026-02-26',
#   'aktualisierungsdatum': '2026-02-26T16:29:12.978',
#   'veroeffentlichungsdatum': '2026-02-26',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Illustrator/in',
#    'Helfer/in - Metallbau',
#    'Industriemechaniker/in'],
#   'ausbildungen': [{'jahr': 2014, 'art': 'Fachhochschulreife'},
#    {'jahr': 2014, 'art': 'Industriemechaniker/in'},
#    {'jahr': 2010, 'art': 'Mittlere Reife / Mittlerer Bildungsabschluss'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Maschinenbau- und Betriebstechnik',
#      'erfahrung': 'P2Y'},
#     {'berufsfeld': 'Kunsthandwerk und bildende Kunst',
#      'erfahrung': 'P3Y1M9D'}],
#    'gesamterfahrung': 'P5Y1M9D'},
#   'letzteTaetigkeit': {'bezeichnung': 'Comic-Zeichner/in', 'aktuell': True},
#   'hatEmail': False,
#   'hatTelefon': True,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Brunsbüttel',
#    'plz': '25541',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205628855-B',
#   'verfuegbarkeitVon': '2026-06-01',
#   'aktualisierungsdatum': '2026-02-26T09:04:15.573',
#   'veroeffentlichungsdatum': '2026-02-26',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT', 'TEILZEIT'],
#   'berufe': ['Gestalter/in - visuelles Marketing'],
#   'expertenKenntnisse': ['Warenpräsentation', 'Verkaufsförderung'],
#   'ausbildungen': [{'jahr': 2002, 'art': 'Schauwerbegestalter/in'},
#    {'jahr': 1998, 'art': 'Fachhochschulreife'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Innenarchitektur, Raumausstattung',
#      'erfahrung': 'P19Y6M26D'}],
#    'gesamterfahrung': 'P19Y6M26D'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Gestalter/in - visuelles Marketing',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Wrist',
#    'plz': '25563',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': True},
#  {'refnr': '10000-1205628768-B',
#   'verfuegbarkeitVon': '2026-03-01',
#   'aktualisierungsdatum': '2026-02-26T08:16:24.755',
#   'veroeffentlichungsdatum': '2026-02-26',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT', 'TEILZEIT'],
#   'berufe': ['Helfer/in - Gartenbau', 'Hausmeister/in'],
#   'ausbildungen': [{'jahr': 2011, 'art': 'Hauptschulabschluss'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Gartenbau',
#      'erfahrung': 'P2Y6M26D'}],
#    'gesamterfahrung': 'P5Y4M15D'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Helfer/in - Gartenbau',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Bad Segeberg',
#    'plz': '23795',
#    'umkreis': '20',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205628278-B',
#   'verfuegbarkeitVon': '2026-05-01',
#   'aktualisierungsdatum': '2026-02-26T07:56:13.634',
#   'veroeffentlichungsdatum': '2026-02-26',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT',
#    'TEILZEIT',
#    'SCHICHT_NACHTARBEIT_WOCHENENDE'],
#   'berufe': ['Tierlehrer/in',
#    'Dozent/in - Hochschulen und Akademien',
#    'Fallmanager/in'],
#   'expertenKenntnisse': ['Arbeitsvorbereitung', 'Personalwesen'],
#   'ausbildungen': [{'jahr': 2010,
#     'art': 'Master of Arts - Advanced Practice in Healthcare (Management and Leadership)'},
#    {'jahr': 1998, 'art': 'Mittlere Reife / Mittlerer Bildungsabschluss'}],
#   'erfahrung': {'gesamterfahrung': 'P8Y4M26D'},
#   'letzteTaetigkeit': {'bezeichnung': 'Lehrer/in/Dozent/in - Erwachsenenbildung',
#    'aktuell': True},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': True,
#   'lokation': {'ort': 'Heide, Holstein',
#    'plz': '25746',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205627912-B',
#   'verfuegbarkeitVon': '2026-02-26',
#   'aktualisierungsdatum': '2026-02-26T07:03:37.979',
#   'veroeffentlichungsdatum': '2026-02-26',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT',
#    'TEILZEIT',
#    'SCHICHT_NACHTARBEIT_WOCHENENDE'],
#   'berufe': ['Helfer/in - Reinigung'],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Reinigung',
#      'erfahrung': 'P4Y1M5D'}],
#    'gesamterfahrung': 'P29Y11M16D'},
#   'letzteTaetigkeit': {'bezeichnung': 'Helfer/in - Reinigung',
#    'aktuell': True},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Kiel',
#    'plz': '24143',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205626859-B',
#   'verfuegbarkeitVon': '2026-02-26',
#   'aktualisierungsdatum': '2026-02-26T06:21:56.934',
#   'veroeffentlichungsdatum': '2026-02-26',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT',
#    'TEILZEIT',
#    'SCHICHT_NACHTARBEIT_WOCHENENDE'],
#   'berufe': ['Helfer/in - Verkauf'],
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Oldenburg in Holstein',
#    'plz': '23758',
#    'umkreis': '10',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205626102-B',
#   'verfuegbarkeitVon': '2026-04-01',
#   'aktualisierungsdatum': '2026-02-26T09:45:14.137',
#   'veroeffentlichungsdatum': '2026-02-26',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['TEILZEIT'],
#   'berufe': ['Personalreferent/in', 'Personalsachbearbeiter/in'],
#   'expertenKenntnisse': ['Einkauf, Beschaffung',
#    'Buchführung, Buchhaltung',
#    'Büro- und Verwaltungsarbeiten'],
#   'ausbildungen': [{'jahr': 2018,
#     'art': 'Bachelor of Arts - BWL - Gesundheitswesen'},
#    {'jahr': 2006, 'art': 'Fachgebundene Hochschulreife'},
#    {'jahr': 2005, 'art': 'Zahnmedizinische/r Fachangestellte/r'}],
#   'erfahrung': {'gesamterfahrung': 'P11Y4M29D'},
#   'letzteTaetigkeit': {'bezeichnung': 'Helfer/in - Büro, Verwaltung',
#    'aktuell': True},
#   'hatEmail': False,
#   'hatTelefon': True,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Neumünster, Holstein',
#    'plz': '24534',
#    'umkreis': '30',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205625863-B',
#   'verfuegbarkeitVon': '2026-02-26',
#   'aktualisierungsdatum': '2026-02-26T06:17:31.364',
#   'veroeffentlichungsdatum': '2026-02-26',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT',
#    'TEILZEIT',
#    'SCHICHT_NACHTARBEIT_WOCHENENDE'],
#   'berufe': ['Helfer/in - Reinigung'],
#   'ausbildungen': [{'jahr': 1990,
#     'art': 'Fachpraktiker/in im Gastgewerbe (§66 BBiG/§42r HwO)'},
#    {'jahr': 1988, 'art': 'Hauptschulabschluss'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Reinigung',
#      'erfahrung': 'P23Y6M7D'}],
#    'gesamterfahrung': 'P25Y5M6D'},
#   'letzteTaetigkeit': {'bezeichnung': 'Helfer/in - Reinigung',
#    'aktuell': True},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Bad Oldesloe',
#    'plz': '23843',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False},
#  {'refnr': '10000-1205621495-B',
#   'verfuegbarkeitVon': '2026-04-01',
#   'aktualisierungsdatum': '2026-02-26T10:49:16.874',
#   'veroeffentlichungsdatum': '2026-02-26',
#   'stellenart': 'ARBEIT',
#   'arbeitszeitModelle': ['VOLLZEIT'],
#   'berufe': ['Ingenieur/in - Stadt- und Regionalplanung',
#    'Stadt- und Regionalplaner/in'],
#   'ausbildungen': [{'jahr': 2017,
#     'art': 'Master of Arts - Städtebau und Ortsplanung'},
#    {'jahr': 2014, 'art': 'Bachelor of Arts - Architektur'},
#    {'jahr': 2009, 'art': 'Raumausstatter/in'},
#    {'jahr': 2006, 'art': 'Allgemeine Hochschulreife'}],
#   'erfahrung': {'berufsfeldErfahrung': [{'berufsfeld': 'Bauplanung und -überwachung, Architektur',
#      'erfahrung': 'P8Y3M25D'}],
#    'gesamterfahrung': 'P8Y3M25D'},
#   'letzteTaetigkeit': {'jahr': '2026',
#    'bezeichnung': 'Stadt- und Regionalplaner/in',
#    'aktuell': False},
#   'hatEmail': False,
#   'hatTelefon': False,
#   'hatAdresse': False,
#   'lokation': {'ort': 'Lübeck',
#    'plz': '23570',
#    'umkreis': '50',
#    'region': 'Schleswig-Holstein',
#    'land': 'Deutschland'},
#   'mehrereArbeitsorte': False}]

# %%
df_bew_SH = json_normalize(bewerber)
df_bew_SH
# Out:
#                           refnr verfuegbarkeitVon     aktualisierungsdatum  \
# 0    10005-135012005101862978-B        2026-02-27  2026-02-27T06:33:30.934
# 1    10005-115171997032452442-B        2026-02-27  2026-02-27T15:40:36.544
# 2    10005-115151997020788885-B        2026-02-27  2026-02-27T10:32:20.314
# 3    10005-115011999100170814-B        2026-02-27  2026-02-27T10:22:01.458
# 4            10000-1205658345-B        2026-02-27  2026-02-27T17:14:34.489
# ..                          ...               ...                      ...
# 245          10000-1205627912-B        2026-02-26  2026-02-26T07:03:37.979
# 246          10000-1205626859-B        2026-02-26  2026-02-26T06:21:56.934
# 247          10000-1205626102-B        2026-04-01  2026-02-26T09:45:14.137
# 248          10000-1205625863-B        2026-02-26  2026-02-26T06:17:31.364
# 249          10000-1205621495-B        2026-04-01  2026-02-26T10:49:16.874
#
#     veroeffentlichungsdatum stellenart  \
# 0                2026-02-27     ARBEIT
# 1                2026-02-27     ARBEIT
# 2                2026-02-27     ARBEIT
# 3                2026-02-27     ARBEIT
# 4                2026-02-27     ARBEIT
# ..                      ...        ...
# 245              2026-02-26     ARBEIT
# 246              2026-02-26     ARBEIT
# 247              2026-02-26     ARBEIT
# 248              2026-02-26     ARBEIT
# 249              2026-02-26     ARBEIT
#
#                                     arbeitszeitModelle  \
# 0                                           [TEILZEIT]
# 1                                 [VOLLZEIT, TEILZEIT]
# 2    [VOLLZEIT, TEILZEIT, SCHICHT_NACHTARBEIT_WOCHE...
# 3    [VOLLZEIT, TEILZEIT, SCHICHT_NACHTARBEIT_WOCHE...
# 4                                           [VOLLZEIT]
# ..                                                 ...
# 245  [VOLLZEIT, TEILZEIT, SCHICHT_NACHTARBEIT_WOCHE...
# 246  [VOLLZEIT, TEILZEIT, SCHICHT_NACHTARBEIT_WOCHE...
# 247                                         [TEILZEIT]
# 248  [VOLLZEIT, TEILZEIT, SCHICHT_NACHTARBEIT_WOCHE...
# 249                                         [VOLLZEIT]
#
#                                                 berufe  hatEmail  hatTelefon  \
# 0                                        [Pförtner/in]     False       False
# 1    [Helfer/in - Büro, Verwaltung, Kaufmann/-frau ...     False       False
# 2                      [Helfer/in - Metallbearbeitung]     False        True
# 3    [Gabelstaplerfahrer/in, Helfer/in - Verkauf, T...     False        True
# 4    [Helfer/in - Lagerwirtschaft, Transport, Gabel...     False       False
# ..                                                 ...       ...         ...
# 245                            [Helfer/in - Reinigung]     False       False
# 246                              [Helfer/in - Verkauf]     False       False
# 247   [Personalreferent/in, Personalsachbearbeiter/in]     False        True
# 248                            [Helfer/in - Reinigung]     False       False
# 249  [Ingenieur/in - Stadt- und Regionalplanung, St...     False       False
#
#      hatAdresse  ...  letzteTaetigkeit.aktuell           lokation.ort  \
# 0         False  ...                     False                  Eutin
# 1         False  ...                     False              Pinneberg
# 2         False  ...                     False              Hemdingen
# 3         False  ...                     False               Elmshorn
# 4         False  ...                     False                   Kiel
# ..          ...  ...                       ...                    ...
# 245       False  ...                      True                   Kiel
# 246       False  ...                       NaN  Oldenburg in Holstein
# 247       False  ...                      True   Neumünster, Holstein
# 248       False  ...                      True           Bad Oldesloe
# 249       False  ...                     False                 Lübeck
#
#     lokation.plz lokation.umkreis     lokation.region lokation.land  \
# 0          23701               20  Schleswig-Holstein   Deutschland
# 1          25421               20  Schleswig-Holstein   Deutschland
# 2          25485               20  Schleswig-Holstein   Deutschland
# 3          25337               25  Schleswig-Holstein   Deutschland
# 4          24109               30  Schleswig-Holstein   Deutschland
# ..           ...              ...                 ...           ...
# 245        24143               50  Schleswig-Holstein   Deutschland
# 246        23758               10  Schleswig-Holstein   Deutschland
# 247        24534               30  Schleswig-Holstein   Deutschland
# 248        23843               50  Schleswig-Holstein   Deutschland
# 249        23570               50  Schleswig-Holstein   Deutschland
#
#                                           ausbildungen  \
# 0                                                  NaN
# 1    [{'jahr': 1990, 'art': 'Kaufmann/-frau - Groß-...
# 2    [{'jahr': 1997, 'art': 'Industriemechaniker/in'}]
# 3               [{'jahr': 2001, 'art': 'Tischler/in'}]
# 4                                                  NaN
# ..                                                 ...
# 245                                                NaN
# 246                                                NaN
# 247  [{'jahr': 2018, 'art': 'Bachelor of Arts - BWL...
# 248  [{'jahr': 1990, 'art': 'Fachpraktiker/in im Ga...
# 249  [{'jahr': 2017, 'art': 'Master of Arts - Städt...
#
#                          erfahrung.berufsfeldErfahrung  \
# 0                                                  NaN
# 1       [{'berufsfeld': 'Handel', 'erfahrung': 'P1Y'}]
# 2                                                  NaN
# 3    [{'berufsfeld': 'Verkauf (ohne Produktspeziali...
# 4                                                  NaN
# ..                                                 ...
# 245  [{'berufsfeld': 'Reinigung', 'erfahrung': 'P4Y...
# 246                                                NaN
# 247                                                NaN
# 248  [{'berufsfeld': 'Reinigung', 'erfahrung': 'P23...
# 249  [{'berufsfeld': 'Bauplanung und -überwachung, ...
#
#                                     expertenKenntnisse  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                  [Beladen, Entladen]
# 4                                                  NaN
# ..                                                 ...
# 245                                                NaN
# 246                                                NaN
# 247  [Einkauf, Beschaffung, Buchführung, Buchhaltun...
# 248                                                NaN
# 249                                                NaN
#
#     freierTitelStellengesuch
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 245                      NaN
# 246                      NaN
# 247                      NaN
# 248                      NaN
# 249                      NaN
#
# [250 rows x 24 columns]

# %%
all_bewerber = []

for page in range(1, 3):  # immer Seite 1 als Minimum haben - geht aber auch Seite 41 bis 81
    query["page"] = page   #oben habe ich size 250 gesetzt, daher kriegt man 250 x Seitenanzahl an Ergebnissen
    url = f"{base}?{up.urlencode(query, safe=';')}"  #250 x 40 = 10000
    
    r = requests.get(url, headers=headers, timeout=30)
    data = r.json()
    
    all_bewerber.extend(data["bewerber"])

df_bew_SH = json_normalize(all_bewerber) #erzeugt die Spaltenform die man unten sehen kann
df_bew_SH = df_bew_SH[[
    #"refnr",
    #"verfuegbarkeitVon",
    #"aktualisierungsdatum",
    #"veroeffentlichungsdatum",
    "stellenart",
    #"arbeitszeitModelle",
    "berufe",
    #"hatEmail",
    #"hatTelefon",
    #"hatAdresse",
    #"mehrereArbeitsorte",
    #"erfahrung.gesamterfahrung",
    "letzteTaetigkeit.jahr",
    "letzteTaetigkeit.bezeichnung",
    #"letzteTaetigkeit.aktuell",
    #"lokation.ort",
    #"lokation.plz",
    #"lokation.umkreis",
    #"lokation.region",
    #"lokation.land",
    #"ausbildungen",
    #"erfahrung.berufsfeldErfahrung",
    #"expertenKenntnisse",
    #"freierTitelStellengesuch"
    ]]
df_bew_SH
# Out:
#     stellenart                                             berufe  \
# 0       ARBEIT                                      [Pförtner/in]
# 1       ARBEIT  [Helfer/in - Büro, Verwaltung, Kaufmann/-frau ...
# 2       ARBEIT                    [Helfer/in - Metallbearbeitung]
# 3       ARBEIT  [Gabelstaplerfahrer/in, Helfer/in - Verkauf, T...
# 4       ARBEIT  [Helfer/in - Lagerwirtschaft, Transport, Gabel...
# ..         ...                                                ...
# 495     ARBEIT  [Bodensteward/-stewardess, Marketingfachkraft/...
# 496     ARBEIT                                [Helfer/in - Küche]
# 497     ARBEIT    [Handelsvertreter/in, Digital-Event-Manager/in]
# 498     ARBEIT    [Helfer/in - Altenpflege/Persönliche Assistenz]
# 499     ARBEIT                              [Gemeindearbeiter/in]
#
#     letzteTaetigkeit.jahr   letzteTaetigkeit.bezeichnung
# 0                    2019          Helfer/in - Reinigung
# 1                    2015              Helfer/in - Küche
# 2                    2013         Industriemechaniker/in
# 3                    2013  Helfer/in - Holz, Flechtwaren
# 4                    2016            Helfer/in - Tiefbau
# ..                    ...                            ...
# 495                   NaN                            NaN
# 496                  2025              Helfer/in - Küche
# 497                  2026            Handelsvertreter/in
# 498                  2026                     Friseur/in
# 499                  2026                 Hausmeister/in
#
# [500 rows x 4 columns]

# %%
df_bew_SH.to_csv("bewerber_SH_500.csv", index=False)
