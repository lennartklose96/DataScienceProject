# %%
#import sys
#!{sys.executable} -m pip install plotly      #falls man noch was installieren muss, geht das hiermit recht leicht

# %%
import requests
import urllib.parse as up
import pandas
from pandas import json_normalize
base = "https://rest.arbeitsagentur.de/jobboerse/jobsuche-service/pc/v4/jobs"
query = {
    "angebotsart": "1",
    "wo": "Berlin",
    #"umkreis": "200",
    #"arbeitszeit": "ho;mj",  # Semikolon bleibt bewusst erhalten
    #"page": "5",
    "size": "250",
    #"pav": "false",
}
# safe=';' sorgt dafür, dass das Semikolon nicht encodiert wird, falls die API es so erwartet
url = f"{base}?{up.urlencode(query, safe=';')}"

headers = {
    "X-API-Key": "jobboerse-jobsuche",
    #"Accept": "application/json",
    #"User-Agent": "Mozilla/5.0",
}

r = requests.get(url, headers=headers, timeout=30)
print("URL:", r.url)
print("Status:", r.status_code, r.reason)
print("CT:", r.headers.get("content-type"))
data= r.json()
# Out:
# URL: https://rest.arbeitsagentur.de/jobboerse/jobsuche-service/pc/v4/jobs?angebotsart=1&wo=Berlin&size=250
# Status: 200 OK
# CT: application/json;charset=UTF-8

# %%
print(data.keys())
# Out:
# dict_keys(['stellenangebote', 'maxErgebnisse', 'page', 'size', 'woOutput', 'facetten'])

# %%
facetten=data["facetten"] #alle möglichen Eigenschaften inklusive der dort vorhanden Daten denke ich mal für Angebotsart 1
facetten                  #aus manchen Eigenschaften werde ich aber noch nicht so richtig schlau, da keine Einheiten gegeben sind
# Out:
# {'befristung': {'counts': {'1': 1098, '2': 21729, '3': 16292},
#   'maxCount': 39119},
#  'verguetung': {'counts': {'jahr': 3104, 'stunde': 10327}, 'maxCount': 39119},
#  'externestellenboersen': {'counts': {'false': 33101, 'true': 6018},
#   'maxCount': 39119},
#  'behinderung': {'counts': {'false': 25797, 'true': 313}, 'maxCount': 39119},
#  'pav': {'counts': {'false': 25990, 'true': 13129}, 'maxCount': 39119},
#  'berufsfeld': {'counts': {'Altenpflege': 1146,
#    'Angehörige der regulären Streitkräfte in sonstigen Rängen': 7,
#    'Arzt- und Praxishilfe': 906,
#    'Aus- und Trockenbau, Isolierung, Zimmerei, Glaserei': 255,
#    'Bau- und Transportgeräteführung': 449,
#    'Bauplanung und -überwachung, Architektur': 893,
#    'Berg-, Tagebau und Sprengtechnik': 13,
#    'Bestattungswesen': 5,
#    'Biologie': 37,
#    'Bodenverlegung': 121,
#    'Buch- und Kunstantiquitäten, Musikfachhandel': 3,
#    'Bühnen- und Kostümbildnerei, Requisite': 2,
#    'Büro und Sekretariat': 1460,
#    'Chemie': 193,
#    'Drucktechnik, Buchbinderei': 91,
#    'Einkauf und Vertrieb': 830,
#    'Elektrotechnik': 972,
#    'Energietechnik': 1173,
#    'Ernährungs- und Gesundheitsberatung': 54,
#    'Erziehung, Sozialarbeit, Heilerziehungspflege': 1731,
#    'Fahr- und Sportunterricht an außerschulischen Bildungseinrichtungen': 50,
#    'Fahrzeug-, Luft-, Raumfahrt- und Schiffbautechnik': 493,
#    'Fahrzeugführung im Eisenbahnverkehr': 33,
#    'Fahrzeugführung im Flugverkehr': 1,
#    'Fahrzeugführung im Schiffsverkehr': 2,
#    'Fahrzeugführung im Straßenverkehr': 1019,
#    'Farb- und Lacktechnik': 52,
#    'Feinwerk- und Werkzeugtechnik': 99,
#    'Fischwirtschaft': 1,
#    'Floristik': 45,
#    'Forstwirtschaft, Jagdwirtschaft, Landschaftspflege': 19,
#    'Gartenbau': 391,
#    'Gastronomie': 504,
#    'Gebäudetechnik': 522,
#    'Geisteswissenschaften': 13,
#    'Geologie, Geografie und Meteorologie': 18,
#    'Geschäftsführung und Vorstand': 18,
#    'Gesellschaftswissenschaften': 127,
#    'Getränkeherstellung': 5,
#    'Gewerbe, Gesundheitsaufsicht, Desinfektion': 32,
#    'Handel': 156,
#    'Hauswirtschaft und Verbraucherberatung': 168,
#    'Hochbau': 420,
#    'Holzbe- und -verarbeitung': 235,
#    'Hotellerie': 277,
#    'Human- und Zahnmedizin': 460,
#    'IT-Netzwerktechnik, -Administration, -Organisation': 757,
#    'IT-Systemanalyse, -Anwendungsberatung und -Vertrieb': 670,
#    'Immobilienwirtschaft und Facility-Management': 455,
#    'Industrielle Glasherstellung': 30,
#    'Industrielle Keramikherstellung': 6,
#    'Informatik': 591,
#    'Innenarchitektur, Raumausstattung': 13,
#    'Kaufleute - Verkehr und Logistik': 180,
#    'Klempnerei, Sanitär-, Heizungs- und Klimatechnik': 732,
#    'Krankenpflege, Rettungsdienst und Geburtshilfe': 1623,
#    'Kunsthandwerk und bildende Kunst': 2,
#    'Kunsthandwerkliche Keramik- und Glasgestaltung': 1,
#    'Kunsthandwerkliche Metallgestaltung': 14,
#    'Kunststoff- und Kautschukherstellung': 105,
#    'Körperpflege': 85,
#    'Lagerwirtschaft, Post und Zustellung, Güterumschlag': 1231,
#    'Landwirtschaft': 33,
#    'Lebensmittel- und Genussmittelherstellung': 249,
#    'Leder- und Pelzherstellung': 13,
#    'Lehr- und Forschungstätigkeit an Hochschulen': 30,
#    'Lehrtätigkeit an allgemeinbildenden Schulen': 91,
#    'Lehrtätigkeit an außerschulischen Bildungseinrichtungen': 38,
#    'Lehrtätigkeit berufsbildender Fächer und betriebliche Ausbildung': 153,
#    'Maler, Stuckateure, Bautenschutz': 342,
#    'Maschinenbau- und Betriebstechnik': 1063,
#    'Mathematik und Statistik': 9,
#    'Mechatronik und Automatisierungstechnik': 445,
#    'Medien-, Dokumentations- und Informationsdienste': 51,
#    'Medizin-, Orthopädie- und Rehatechnik': 166,
#    'Medizinisches Laboratorium': 186,
#    'Metallbau und Schweißtechnik': 436,
#    'Metallbearbeitung': 580,
#    'Metallerzeugung': 12,
#    'Metalloberflächenbehandlung': 36,
#    'Museumstechnik und -management': 4,
#    'Musik-, Gesang-, Dirigententätigkeiten': 3,
#    'Musikinstrumentenbau': 1,
#    'Naturstein- und Mineralaufbereitung, Baustoffherstellung': 14,
#    'Nichtärztliche Therapie und Heilkunde': 838,
#    'Objekt-, Personen-, Brandschutz, Arbeitssicherheit': 715,
#    'Offiziere': 1,
#    'Papier- und Verpackungstechnik': 57,
#    'Personalwesen und -dienstleistung': 399,
#    'Pferdewirtschaft': 9,
#    'Pharmazie': 54,
#    'Physik': 48,
#    'Polizei- und Kriminaldienst, Gerichts- und Justizvollzug': 2,
#    'Produkt- und Industriedesign': 2,
#    'Psychologie, nichtärztliche Psychotherapie': 164,
#    'Rechnungswesen, Controlling und Revision': 840,
#    'Rechtsberatung, -sprechung und -ordnung': 351,
#    'Redaktion und Journalismus': 30,
#    'Reinigung': 1042,
#    'Servicekräfte im Personenverkehr': 14,
#    'Softwareentwicklung und Programmierung': 563,
#    'Speisenzubereitung': 871,
#    'Sprach- und Literaturwissenschaften': 2,
#    'Steuerberatung': 311,
#    'Technische Forschung und Entwicklung': 120,
#    'Technische Mediengestaltung': 57,
#    'Technische Produktionsplanung und -steuerung': 333,
#    'Technischer Betrieb des Eisenbahn-, Luft- und Schiffsverkehrs': 25,
#    'Technisches Zeichnen, Konstruktion und Modellbau': 135,
#    'Textiltechnik und -produktion': 21,
#    'Textilverarbeitung': 35,
#    'Theater-, Film- und Fernsehproduktion': 4,
#    'Theologie und Gemeindearbeit': 1,
#    'Tiefbau': 271,
#    'Tiermedizin und Tierheilkunde': 6,
#    'Tierpflege': 8,
#    'Tierwirtschaft': 4,
#    'Tourismus und Sport': 34,
#    'Umweltmanagement und -beratung': 31,
#    'Umweltschutztechnik': 10,
#    'Unternehmensorganisation und -strategie': 827,
#    'Unteroffiziere mit Portepee': 22,
#    'Unteroffiziere ohne Portepee': 5,
#    'Ver- und Entsorgung': 367,
#    'Veranstaltungs-, Kamera-, Tontechnik': 42,
#    'Veranstaltungsservice und -management': 52,
#    'Verkauf (ohne Produktspezialisierung)': 2288,
#    'Verkauf Bekleidung, Elektro, KFZ, Hartwaren': 339,
#    'Verkauf von Lebensmitteln': 223,
#    'Verkauf von drogerie- und apothekenüblichen Waren': 55,
#    'Verlags- und Medienwirtschaft': 7,
#    'Vermessung und Kartografie': 44,
#    'Versicherungs- und Finanzdienstleistungen': 377,
#    'Verwaltung': 317,
#    'Werbung und Marketing': 694,
#    'Wirtschaftswissenschaften': 2,
#    'Öffentlichkeitsarbeit': 19,
#    'Überwachung und Steuerung des Verkehrsbetriebs': 60,
#    'Überwachung, Wartung Verkehrsinfrastruktur': 20},
#   'maxCount': 39119},
#  'arbeitsort': {'counts': {'Wildau bei Königs Wusterhausen': 139,
#    'Schönefeld bei Berlin': 410,
#    'Bernau bei Berlin': 344,
#    'Berlin': 35273,
#    'Blankenfelde-Mahlow': 246,
#    'Stahnsdorf': 91,
#    'Fredersdorf-Vogelsdorf': 75,
#    'Erkner': 85,
#    'Hoppegarten (Mark)': 230,
#    'Ahrensfelde bei Berlin': 114,
#    'Neuenhagen bei Berlin': 108,
#    'Kleinmachnow': 124,
#    'Falkensee': 170,
#    'Hohen Neuendorf': 130,
#    'Großbeeren': 294,
#    'Teltow': 263,
#    'Hennigsdorf': 415},
#   'maxCount': 39119},
#  'veroeffentlichtseit': {'counts': {'0': 1353,
#    '1': 2499,
#    '14': 12714,
#    '28': 21179,
#    '7': 7446,
#    'alle': 39119},
#   'maxCount': 39119},
#  'weitereberufe': {'counts': {'Abgeschlossene Berufsausbildung': 3,
#    'Baufinanzierungsspezialist': 3,
#    'Bauhelfer': 3,
#    'Bauingenieur/in': 5,
#    'Bauzeichner': 3,
#    'Berufserfahrung': 3,
#    'Berufsorientierung': 3,
#    'Call Center Agent m/w/d': 4,
#    'Chef de Partie': 3,
#    'Drucker/in': 3,
#    'Drucker/in - Offset': 3,
#    'Elektriker': 17,
#    'Elektriker/in': 3,
#    'Elektroinstallateur/in': 3,
#    'Elektromonteur': 3,
#    'Elektroniker': 10,
#    'Elektroniker/in': 4,
#    'Elektrotechniker': 3,
#    'Energieberater m/w/d': 4,
#    'Erzieher/in': 3,
#    'F&B Manger/in': 3,
#    'Facility Management': 4,
#    'Fenster- und Türenbauer/in': 6,
#    'Fensterbauer': 5,
#    'Forderungsmangement': 12,
#    'Front Office': 6,
#    'Front Office Manager': 3,
#    'Gebäudetechnik': 3,
#    'Gesundheitspfleger/in': 6,
#    'Handwerker': 3,
#    'Hausmeister': 9,
#    'Haustechniker': 9,
#    'Hausverwaltung': 6,
#    'Hauswart': 4,
#    'Hauswirtschaftskraft': 3,
#    'Heilerziehungspfleger/in': 3,
#    'Heizungsbauer': 8,
#    'Helfer': 5,
#    'Immobilienwirtschaft': 6,
#    'Innenausbauer/in': 6,
#    'Kaufmann/-frau - Einzelhandel': 3,
#    'Kaufmann/-frau - Einzelhandel (Elektrogeräte)': 3,
#    'Kaufmann/-frau - Einzelhandel (Heimw./Pflanz./Garten/Zoo)': 3,
#    'Kaufmännischer Leiter': 6,
#    'Klempner': 22,
#    'Koch/in': 6,
#    'Kosmetiker/in': 7,
#    'Kraftfahrzeugelektriker/in': 5,
#    'Kraftfahrzeugmechaniker/in': 3,
#    'Kraftfahrzeugmechatroniker/in - Motorradtechnik': 5,
#    'Kraftfahrzeugmechatroniker/in - Personenkraftwagentechnik': 5,
#    'Kraftfahrzeugservicemechaniker/in': 5,
#    'Krankenpfleger/in': 7,
#    'Krankenschwester': 3,
#    'Kundenberater m/w/d': 16,
#    'Kundenbetreuer m/w/d': 4,
#    'Küchenchef/in': 3,
#    'Küchenleitung': 3,
#    'Lackierer': 7,
#    'Lehrer': 4,
#    'Maler': 7,
#    'Masseur/in': 6,
#    'Meister HKLS': 4,
#    'Meister/in - Kraftverkehr': 3,
#    'Metallbauer': 6,
#    'Monteur': 3,
#    'Office Manager': 8,
#    'Pflegefachkraft': 6,
#    'Pflegehelfer/in': 5,
#    'Pflegehilfskraft': 4,
#    'Pflegekraft': 3,
#    'Produktionsmitarbeiter': 3,
#    'Restaurant': 12,
#    'Restaurantleiter/in': 7,
#    'Sachbearbeiter m/w/d': 16,
#    'Sales Agent m/w/d': 3,
#    'Schlosser': 4,
#    'Schreiner/in': 8,
#    'Schuldenberatung': 12,
#    'Servicekraft': 6,
#    'Servicetechniker': 6,
#    'Servicetechniker/in': 3,
#    'Soldat auf Zeit': 3,
#    'Sozialarbeiter *in': 3,
#    'Sozialpädagoge': 3,
#    'Sportlehrer': 4,
#    'Techn.-Leiter/in': 6,
#    'Techniker': 4,
#    'Techniker HKLS': 4,
#    'Technische Ausbildung mit Bezug zur Gebäudetechnik': 3,
#    'Telefonische und schriftliche Kundenberatung': 4,
#    'Telefonischer Kundenberater m/w/d': 7,
#    'Tischler': 7,
#    'Treppenbauer': 4,
#    'Treppenbauer/in': 6,
#    'Veranstaltungen organisieren': 3,
#    'Verkaufsberater/in': 3,
#    'Verkäufer m/w/d': 3,
#    'Vertriebler m/w/d': 3,
#    'bundesweiter Einsatz möglich !': 9},
#   'maxCount': 39119},
#  'schulbildung': {'counts': {'0': 2, '6': 1}, 'maxCount': 39119},
#  'arbeitsort_plz': {'counts': {'01067': 148,
#    '04109': 285,
#    '07745': 158,
#    '10115': 1532,
#    '10117': 1627,
#    '10119': 211,
#    '10178': 1317,
#    '10179': 620,
#    '10243': 571,
#    '10245': 410,
#    '10247': 231,
#    '10249': 294,
#    '10315': 350,
#    '10317': 240,
#    '10318': 347,
#    '10319': 249,
#    '10365': 499,
#    '10367': 229,
#    '10369': 292,
#    '10405': 281,
#    '10407': 171,
#    '10409': 124,
#    '10435': 155,
#    '10437': 276,
#    '10439': 149,
#    '10551': 222,
#    '10553': 327,
#    '10555': 129,
#    '10557': 243,
#    '10559': 165,
#    '10585': 175,
#    '10587': 858,
#    '10589': 142,
#    '10623': 368,
#    '10625': 233,
#    '10627': 127,
#    '10707': 146,
#    '10709': 216,
#    '10711': 92,
#    '10713': 119,
#    '10719': 481,
#    '10777': 100,
#    '10783': 98,
#    '10785': 453,
#    '10787': 257,
#    '10789': 390,
#    '10825': 109,
#    '10827': 115,
#    '10829': 308,
#    '10961': 185,
#    '10963': 293,
#    '10965': 167,
#    '10967': 179,
#    '10969': 374,
#    '10997': 186,
#    '10999': 177,
#    '12043': 213,
#    '12045': 180,
#    '12047': 119,
#    '12049': 134,
#    '12051': 154,
#    '12053': 125,
#    '12055': 152,
#    '12057': 236,
#    '12059': 178,
#    '12099': 461,
#    '12101': 119,
#    '12103': 172,
#    '12105': 90,
#    '12107': 128,
#    '12157': 125,
#    '12159': 130,
#    '12161': 102,
#    '12163': 1122,
#    '12165': 151,
#    '12167': 130,
#    '12169': 123,
#    '12203': 84,
#    '12247': 276,
#    '12249': 117,
#    '12277': 367,
#    '12307': 176,
#    '12309': 227,
#    '12347': 164,
#    '12351': 161,
#    '12359': 109,
#    '12435': 210,
#    '12459': 112,
#    '12487': 307,
#    '12489': 728,
#    '12526': 144,
#    '12527': 192,
#    '12529': 407,
#    '12555': 208,
#    '12557': 97,
#    '12587': 95,
#    '12619': 207,
#    '12621': 264,
#    '12623': 299,
#    '12627': 302,
#    '12629': 173,
#    '12679': 197,
#    '12681': 1896,
#    '12683': 480,
#    '12685': 190,
#    '12687': 177,
#    '12689': 183,
#    '13051': 172,
#    '13053': 297,
#    '13055': 234,
#    '13057': 136,
#    '13059': 133,
#    '13086': 144,
#    '13088': 292,
#    '13089': 125,
#    '13125': 266,
#    '13127': 142,
#    '13129': 103,
#    '13156': 112,
#    '13158': 199,
#    '13187': 236,
#    '13189': 106,
#    '13347': 279,
#    '13349': 105,
#    '13351': 90,
#    '13353': 1077,
#    '13355': 274,
#    '13357': 290,
#    '13359': 253,
#    '13403': 348,
#    '13405': 239,
#    '13407': 434,
#    '13409': 275,
#    '13437': 150,
#    '13439': 196,
#    '13467': 90,
#    '13469': 143,
#    '13505': 125,
#    '13507': 337,
#    '13509': 352,
#    '13581': 249,
#    '13585': 182,
#    '13587': 180,
#    '13589': 115,
#    '13591': 191,
#    '13597': 234,
#    '13599': 191,
#    '13627': 198,
#    '13629': 528,
#    '14052': 114,
#    '14059': 143,
#    '14089': 94,
#    '14109': 120,
#    '14129': 106,
#    '14163': 220,
#    '14165': 106,
#    '14167': 242,
#    '14193': 318,
#    '14195': 87,
#    '14199': 107,
#    '14513': 243,
#    '14532': 208,
#    '14612': 162,
#    '14974': 202,
#    '14979': 273,
#    '15366': 334,
#    '15370': 87,
#    '15537': 94,
#    '15745': 139,
#    '15827': 134,
#    '15831': 91,
#    '16321': 341,
#    '16356': 161,
#    '16540': 110,
#    '16761': 383,
#    '20095': 112,
#    '20097': 140,
#    '20148': 180,
#    '20457': 138,
#    '22085': 119,
#    '22587': 142,
#    '28195': 119,
#    '30159': 171,
#    '33605': 86,
#    '40213': 207,
#    '44139': 106,
#    '50667': 250,
#    '50676': 83,
#    '51063': 106,
#    '53119': 138,
#    '60313': 124,
#    '60486': 176,
#    '65760': 222,
#    '70173': 207,
#    '70629': 181,
#    '80331': 348,
#    '80636': 204,
#    '80807': 93,
#    '89075': 146,
#    '90402': 223},
#   'maxCount': 39119},
#  'arbeitgeber': {'counts': {'ALLPOWER Personalprofis GmbH': 45,
#    'AMBAU Personalservice GmbH': 40,
#    'Actief Personalmanagement GmbH Berlin': 85,
#    'Akzent Personaldienstleistungen Mitte GmbH': 64,
#    'Albert Schweitzer Stiftung Wohnen & Betreuen': 67,
#    'Alexianer St. Hedwig Kliniken GmbH': 40,
#    'AlphaConsult KG - BS Berllin': 45,
#    'Apleona GmbH': 60,
#    'Arena Personal Mgmt. GmbH': 45,
#    'BWI GmbH': 183,
#    'Bundesamt für das Personalmanagement der Bundeswehr': 39,
#    'Charité Universitätsmedizin Berlin KdöR': 51,
#    'Computacenter AG & Co. oHG': 38,
#    'DIEPA GmbH Filiale Berlin Südost': 139,
#    'DIS AG': 147,
#    'Deloitte GmbH': 219,
#    'Der Rote Punkt Medizinische Personalvermittlung med Heike Müller-Weging': 545,
#    'Deutsche Bahn AG': 230,
#    'Deutsche Rentenversicherung Bund': 43,
#    'Die Jobtimisten e. K.': 154,
#    'Dipl.-Ing. Gennadi Rouditser D.I.R.A. Arbeitsvermittlung & Unternehmensberatung': 85,
#    'EPOS Personaldienstleistungen GmbH-Berlin': 48,
#    'EY Consulting GmbH': 103,
#    'EY Tax GmbH Steuerberatungsgesellschaft': 44,
#    'Einzelunternehmen Job Zentrum Arbeitsvermittlung': 143,
#    'FERCHAU GmbH Niederlassung Berlin Süd': 151,
#    'Findehotelpersonal GmbH': 45,
#    'GOLDBECK GmbH': 55,
#    'GS Company Cottbus GmbH & Co. KG': 46,
#    'GS-COMPANY GmbH & Co. KG': 89,
#    'Go.med Personaldienstleistung GmbH': 84,
#    'HELIOS Klinikum Berlin-Buch GmbH': 63,
#    'HelloFresh SE': 50,
#    'I. K. Hofmann GmbH': 50,
#    'IBS GmbH': 49,
#    'IMS Personal GmbH': 46,
#    'Impuls Personal GmbH': 64,
#    'Jan Schreiner Private Arbeitsvermittlung Arbitex': 374,
#    'JobImpulse Nord GmbH': 53,
#    'Johannesstift Diakonie gAG': 337,
#    'KORIAN Holding GmbH': 40,
#    'Kaufland Dienstleistung GmbH & Co. KG': 106,
#    'Kummer Consulting GmbH': 40,
#    'König Fachpersonal GmbH & Co KG, Niederlassung Berlin': 83,
#    'LIDL Vertriebs-GmbH & Co. KG': 198,
#    'Lidl Vertriebs-GmbH & Co. KG Freienbrink': 41,
#    'MW PowerEngineering GmbH': 61,
#    'Manpower GmbH & Co. KG Unternehmensbereich Industrie': 96,
#    'Mike Jirschinetz-Degenhardt Arbeitsvermittlung': 61,
#    'NTT DATA Business Solutions Global Managed Services GmbH': 85,
#    'NTT DATA Deutschland SE': 65,
#    'Neo Temp GmbH': 477,
#    'Netto Marken-Discount Stiftung & Co. KG': 355,
#    'PAV Herzog': 78,
#    'Page Personnel Deutschland': 44,
#    'Penny-Markt GmbH Ost': 54,
#    'PerZukunft Arbeitsvermittlung GmbH&Co.KG': 7389,
#    'Permacon GmbH': 71,
#    'Perso Plankontor GmbH': 105,
#    'Pflegia GmbH': 291,
#    'Piening GmbH': 52,
#    'Primestaff GmbH': 86,
#    'RADAS Jobbörse & Personalvermittlung GmbH': 160,
#    'REWE Markt GmbH ZwNL Ost': 181,
#    'Randstad Deutschland': 109,
#    'Riverstate International Consulting GmbH': 54,
#    'SPITZKE SE': 61,
#    'Sanovetis GmbH': 75,
#    'Senatsverwaltung für Bildung, Jugend und Familie (Schule)': 89,
#    'Siemens AG': 55,
#    'Siemens Energy Global GmbH & Co. KG': 98,
#    'Stewe Personalservice GmbH & Co. KG - Niederlassung Berlin': 52,
#    'Stromnetz Berlin GmbH': 49,
#    'TEDi GmbH & Co. KG': 96,
#    'TEMPTON Personaldienstleistungen GmbH': 48,
#    'Tempton Personaldienstleistungen GmbH': 69,
#    'Tempton Personaldienstleistungen GmbH NL Berlin Medical': 46,
#    'Tesla Germany GmbH': 87,
#    'TimePartner Personalmanagement GmbH': 254,
#    'Unique Personalservice GmbH': 39,
#    'Unit Personalservice GmbH': 92,
#    'Vitanas GmbH & Co. KGaA Verwaltung': 75,
#    'Vivantes Netzwerk für Gesundheit GmbH': 418,
#    'Volkssolidarität Berlin e. V.': 42,
#    'W & W Human Resources Ivonne Wresch, Anja Weber': 68,
#    'WISAG Job & Karriere GmbH & Co. KG': 116,
#    'WS Personaldienstleistungen GmbH': 172,
#    'Workwise GmbH': 57,
#    'all.medi Personallogistik GmbH': 44,
#    'biac Personalservice GmbH NL Medizin/ Soziales': 157,
#    'dennree GmbH': 67,
#    'eMARK Marketing GmbH': 176,
#    'iperdi HL GmbH - Niederlassung Potsdam': 49,
#    'maXXu Personalvermittlung Heiko Werner': 246,
#    'persona service AG & Co. KG Berlin-Mitte': 40,
#    'persona service AG & Co. KG Berlin-Neukölln': 47,
#    'persona service AG & Co.KG Berlin Wedding': 39,
#    'puro Personaldienstleistung GmbH': 55,
#    'secunet Security Networks AG': 45,
#    'zollsoft GmbH': 47},
#   'maxCount': 39119},
#  'beruf': {'counts': {'Altenpflegehelfer/in': 485,
#    'Altenpfleger/in': 708,
#    'Anlagenmechaniker/in': 244,
#    'Anlagenmechaniker/in - Sanitär-, Heizungs- und Klimatechnik': 552,
#    'Architekt/in': 176,
#    'Arzthelfer/in': 246,
#    'Auslieferungsfahrer/in (nicht Verkaufsfahrer/in)': 347,
#    'Außendienstmitarbeiter/in': 148,
#    'Bauleiter/in': 306,
#    'Beikoch/-köchin': 338,
#    'Berufskraftfahrer/in': 784,
#    'Betreuungskraft / Alltagsbegleiter/in': 244,
#    'Betriebsschlosser/in': 267,
#    'Buchhalter/in': 434,
#    'Büroassistent/in': 243,
#    'Bürokaufmann/-frau': 812,
#    'Callcenteragent/in': 466,
#    'Dienstwagenfahrer/in': 148,
#    'Einzelhandelskaufmann/-frau': 372,
#    'Elektroanlagenmonteur/in': 202,
#    'Elektroinstallateur/in': 506,
#    'Elektroniker/in - Betriebstechnik': 351,
#    'Elektroniker/in - Energie- und Gebäudetechnik': 446,
#    'Elektroniker/in - Geräte und Systeme': 165,
#    'Empfangskraft': 173,
#    'Ergotherapeut/in': 281,
#    'Erzieher/in': 678,
#    'Fachinformatiker/in - Systemintegration': 194,
#    'Fachkraft - Lagerlogistik': 297,
#    'Fachlagerist/in': 218,
#    'Filialleiter/in, Verkaufsstellenleiter/in': 239,
#    'Finanzbuchhalter/in': 262,
#    'Gabelstaplerfahrer/in': 408,
#    'Gas- und Wasserinstallateur/in': 268,
#    'Gebäudereiniger/in': 650,
#    'Gesundheits- und Krankenpflegehelfer/in': 252,
#    'Gesundheits- und Krankenpfleger/in': 756,
#    'Glasreiniger/in': 149,
#    'Gärtner/in - Garten- und Landschaftsbau': 197,
#    'Hausmeister/in': 322,
#    'Hauswart/in/Haustechniker/in': 301,
#    'Heilerziehungspfleger/in': 169,
#    'Helfer/in - Altenpflege/Persönliche Assistenz': 160,
#    'Helfer/in - Ausbau': 151,
#    'Helfer/in - Elektro': 201,
#    'Helfer/in - Gartenbau': 244,
#    'Helfer/in - Gastgewerbe': 318,
#    'Helfer/in - Hauswirtschaft': 144,
#    'Helfer/in - Küche': 545,
#    'Helfer/in - Lagerwirtschaft, Transport': 719,
#    'Helfer/in - Lebensmittelherstellung': 144,
#    'Helfer/in - Reinigung': 785,
#    'Helfer/in - Verkauf': 578,
#    'Hochbauingenieur/in': 149,
#    'IT-Berater/in': 386,
#    'IT-Systemadministrator/in': 237,
#    'Immobilienkaufmann/-frau': 245,
#    'Industrieelektriker/in - Betriebstechnik': 189,
#    'Industriekaufmann/-frau': 222,
#    'Industriemechaniker/in': 507,
#    'Informatiker/in': 274,
#    'Ingenieur/in - Bau': 470,
#    'Ingenieur/in - Elektrotechnik': 379,
#    'Kassierer/in (Handel)': 519,
#    'Kaufmann/-frau - Bürokommunikation': 244,
#    'Kaufmann/-frau - Büromanagement': 387,
#    'Kaufmann/-frau - Einzelhandel': 431,
#    'Kaufmännische Fachkraft': 270,
#    'Koch/Köchin': 379,
#    'Kommissionierer/in': 381,
#    'Kraftfahrzeugmechatroniker/in - Personenkraftwagentechnik': 167,
#    'Krankenschwester/-pfleger': 245,
#    'Lager- und Transportarbeiter/in': 569,
#    'Maler/in und Lackierer/in - Maler/in': 205,
#    'Maschinen- und Anlagenführer/in (ohne Angabe des Schwerpunkts)': 315,
#    'Mechatroniker/in': 545,
#    'Medizinische/r Fachangestellte/r': 641,
#    'Metallbauer/in - Konstruktionstechnik': 161,
#    'Personalsachbearbeiter/in': 159,
#    'Pflegedienstleiter/in': 209,
#    'Pflegefachmann/-frau (Altenpflege)': 524,
#    'Pflegefachmann/-frau (Ausbildung)': 302,
#    'Pflegefachmann/-frau (Gesundheits- und Krankenpflege)': 291,
#    'Physiotherapeut/in': 449,
#    'Projektleiter/in': 229,
#    'Psychologe/Psychologin': 155,
#    'Pädagoge/Pädagogin': 179,
#    'Sales-Manager/in': 185,
#    'Servicekraft - Gastronomie und Gastgewerbe': 295,
#    'Servicekraft - Schutz und Sicherheit': 162,
#    'Sicherheitsmitarbeiter/in': 493,
#    'Softwareentwickler/in': 295,
#    'Sozialarbeiter/in / Sozialpädagoge/-pädagogin': 617,
#    'Steuerfachangestellte/r': 248,
#    'Telefonist/in': 234,
#    'Tischler/in': 242,
#    'Verkäufer/in': 1633,
#    'Vertriebsberater/in': 162,
#    'Zahnmedizinische/r Fachangestellte/r': 210,
#    'Zerspanungsmechaniker/in': 265},
#   'maxCount': 39119},
#  'branche': {'counts': {'1': 1991,
#    '10': 491,
#    '11': 852,
#    '12': 184,
#    '13': 2865,
#    '14': 29,
#    '15': 409,
#    '16': 17,
#    '17': 163,
#    '18': 782,
#    '19': 131,
#    '2': 126,
#    '20': 1,
#    '21': 408,
#    '22': 295,
#    '23': 723,
#    '24': 96,
#    '25': 73,
#    '26': 7,
#    '27': 6799,
#    '28': 5212,
#    '29': 580,
#    '3': 334,
#    '4': 412,
#    '5': 232,
#    '6': 427,
#    '7': 2945,
#    '8': 118,
#    '9': 2119},
#   'maxCount': 39119},
#  'quereinstieg': {'counts': {'false': 35694, 'true': 3425}, 'maxCount': 39119},
#  'arbeitszeit': {'counts': {'ho': 534,
#    'mj': 656,
#    'snw': 3796,
#    'tz': 11062,
#    'vz': 33503},
#   'maxCount': 39119},
#  'eintrittsdatum': {'counts': {'10_01_01-now': 34255,
#    '26_02_01-26_03_01': 28318,
#    '26_03_01-26_04_01': 3151,
#    '26_04_01-26_05_01': 756,
#    '26_05_01-26_06_01': 227,
#    '26_06_01-26_07_01': 58,
#    '26_07_01-26_08_01': 39,
#    '26_08_01-26_09_01': 70,
#    '26_09_01-26_10_01': 11,
#    '26_10_01-26_11_01': 20,
#    '26_11_01-26_12_01': 5,
#    '26_12_01-27_01_01': 28,
#    '27_01_01-27_02_01': 3,
#    '27_02_01-27_03_01': 1,
#    '27_03_01-27_04_01': 1,
#    '27_04_01-27_05_01': 1,
#    '28_01_01-28_02_01': 2},
#   'maxCount': 39119},
#  'zeitarbeit': {'counts': {'false': 33798, 'true': 5321}, 'maxCount': 39119}}

# %%
#print(data.get("stellenangebote"))

# %%
jobs=data["stellenangebote"]
jobs
# Out:
# [{'beruf': 'Fachinformatiker/in - Systemintegration',
#   'titel': 'Fachinformatiker Systemintegration (m/w/d)',
#   'refnr': '10001-1002668920-S',
#   'arbeitsort': {'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.5112613, 'lon': 13.4255145},
#    'entfernung': '0'},
#   'arbeitgeber': 'NConsult GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-26',
#   'modifikationsTimestamp': '2026-02-26T08:51:46.333',
#   'eintrittsdatum': '2026-02-26',
#   'kundennummerHash': 'j0aPmLopen8lCLYNYFVQvSNU_Zt6R8pPPsn8NWUkVbA='},
#  {'beruf': 'Fachinformatiker/in - Systemintegration',
#   'titel': 'Junior IT-Administrator (m/w/d)',
#   'refnr': '10001-1002668890-S',
#   'arbeitsort': {'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.5112613, 'lon': 13.4255145},
#    'entfernung': '0'},
#   'arbeitgeber': 'NConsult GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-26',
#   'modifikationsTimestamp': '2026-02-26T08:49:38.098',
#   'eintrittsdatum': '2026-02-26',
#   'kundennummerHash': 'j0aPmLopen8lCLYNYFVQvSNU_Zt6R8pPPsn8NWUkVbA='},
#  {'beruf': 'IT-Administrator/in',
#   'titel': 'IT-Administrator (m/w/d)',
#   'refnr': '10001-1002668867-S',
#   'arbeitsort': {'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.5112613, 'lon': 13.4255145},
#    'entfernung': '0'},
#   'arbeitgeber': 'NConsult GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-26',
#   'modifikationsTimestamp': '2026-02-26T08:47:45.586',
#   'eintrittsdatum': '2026-02-26',
#   'kundennummerHash': 'j0aPmLopen8lCLYNYFVQvSNU_Zt6R8pPPsn8NWUkVbA='},
#  {'beruf': 'Fachinformatiker/in - Systemintegration',
#   'titel': 'Senior IT-ADMINISTRATOR (m/w/d)',
#   'refnr': '10001-1002668843-S',
#   'arbeitsort': {'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.5112613, 'lon': 13.4255145},
#    'entfernung': '0'},
#   'arbeitgeber': 'NConsult GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-26',
#   'modifikationsTimestamp': '2026-02-26T08:45:43.656',
#   'eintrittsdatum': '2026-02-26',
#   'kundennummerHash': 'j0aPmLopen8lCLYNYFVQvSNU_Zt6R8pPPsn8NWUkVbA='},
#  {'beruf': 'Koch/Köchin',
#   'titel': 'Commis de Cuisine (d/w/m) Vollaziet - 12727',
#   'refnr': '10001-1002678734-S',
#   'arbeitsort': {'plz': '10243',
#    'ort': 'Berlin',
#    'strasse': 'An der Schillingsbrücke 2',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.509861, 'lon': 13.429593},
#    'entfernung': '0'},
#   'arbeitgeber': 'SV (Deutschland) GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T10:23:46.076',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': '84-8uV3BkgpYbyToJNsi1u_jtV9gsIIgoyuw8DlIWVM='},
#  {'beruf': 'Elektroniker/in - Energie- und Gebäudetechnik',
#   'titel': 'Technischer Leiter (d/w/m) - 13167',
#   'refnr': '10001-1002677789-S',
#   'arbeitsort': {'plz': '10243',
#    'ort': 'Berlin',
#    'strasse': 'An der Schillingsbrücke 2',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.509861, 'lon': 13.429593},
#    'entfernung': '0'},
#   'arbeitgeber': 'SV (Deutschland) GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T10:12:35.57',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': '84-8uV3BkgpYbyToJNsi1u_jtV9gsIIgoyuw8DlIWVM='},
#  {'beruf': 'Leiter/in - Informations-/Cybersicherheit',
#   'titel': 'Referent/-in für Grundsatzangelegenheiten Informationssicherheit /  Notfallmanagement in der Abteilu',
#   'refnr': '14795-64046_116197-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.5132279, 'lon': 13.4157237},
#    'entfernung': '1'},
#   'arbeitgeber': 'Senatsverwaltung f. Mobilität, Verkehr, Klimaschutz und Umwelt',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T11:01:32.823',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'I7fuUNwyKzfj4-b1YSa55WxE0oRO1tQXQMXFz9Rzuw8='},
#  {'beruf': 'Medizinische/r Fachangestellte/r',
#   'titel': 'Medizinische Fachangestellte MFA (m/w/d) bis 24 EUR Bruttostundenlohn',
#   'refnr': '18248-L1KIVQJ6BZ7HRJLY-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.5132279, 'lon': 13.4157237},
#    'entfernung': '1'},
#   'arbeitgeber': 'Med-Spezialisten GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T10:58:02.724',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'Zp6sJ4hyBKQQIS1UrfBZi4sCDybtw-pEFlCYnSfgXoE='},
#  {'beruf': 'Marketingfachkraft/-assistent/in',
#   'titel': 'B2B Event Marketing Manager (f/m/d)',
#   'refnr': '13635-61eee016_JB5080629-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.5132279, 'lon': 13.4157237},
#    'entfernung': '1'},
#   'arbeitgeber': 'SPREAD GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T10:55:57.487',
#   'eintrittsdatum': '2026-02-27',
#   'externeUrl': 'https://www.jobexport.de/job/5080629.html?exp=81&cid=61eee016-437c-40a2-a9a4-a6146577cdfc'},
#  {'beruf': 'Barmixer/in, Barkeeper/in',
#   'titel': 'Aushilfe Bar (m/w/d)',
#   'refnr': '12518-KBMC0B-SRC-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.5132279, 'lon': 13.4157237},
#    'entfernung': '1'},
#   'arbeitgeber': 'Motel One Berlin - Hackescher Markt',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T07:02:14.718',
#   'eintrittsdatum': '2026-03-15',
#   'externeUrl': 'https://www.hogapage.de/jobs/barkeeper-in-berlin/KBMC0B-SRC/?hp_source=api-arbeitsamt&utm_medium=API&utm_source=arbeitsamt'},
#  {'beruf': 'Barmixer/in, Barkeeper/in',
#   'titel': 'Barkeeper (m/w/d)',
#   'refnr': '12518-9QSZK1-TRX-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.5132279, 'lon': 13.4157237},
#    'entfernung': '1'},
#   'arbeitgeber': 'Motel One Berlin - Hackescher Markt',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T07:02:14.65',
#   'eintrittsdatum': '2026-03-15',
#   'externeUrl': 'https://www.hogapage.de/jobs/barkeeper-in-berlin/9QSZK1-TRX/?hp_source=api-arbeitsamt&utm_medium=API&utm_source=arbeitsamt'},
#  {'beruf': 'Beikoch/-köchin',
#   'titel': 'Küchenhelfer/Spüler (m/w/d) für Gasthof gesucht 19,36€/Std',
#   'refnr': '12016-10004038200-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T17:41:18.784',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'QCGqch7PL50CBjk6teuMzDX913ummnZAOsdgVWgX3GY='},
#  {'beruf': 'Pförtner/in',
#   'titel': 'Sicherheitskraft / Bewacher - unbefristete Anstellung m/w/d',
#   'refnr': '12016-10004041975-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T16:32:17.879',
#   'eintrittsdatum': '2026-02-28',
#   'kundennummerHash': '2vEM2N0NLlEG-XTOdlkJO7u1PwQqDBz6ruvkeOsW_hM='},
#  {'beruf': 'Lager- und Transportarbeiter/in',
#   'titel': 'Lagerhelfer (m/w/d) Kosmetikbranche -17,12 EUR - Wilmersdorf',
#   'refnr': '12016-10004041537-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T16:32:17.558',
#   'eintrittsdatum': '2026-03-01',
#   'kundennummerHash': 'K-odMSiWh6Flr85j5gueeE_9FFhpOtsHIPbrBKoeCCs='},
#  {'beruf': 'Psychologe/Psychologin',
#   'titel': 'Psychologe - Sucht m/w/d -  Attraktives Gehalt',
#   'refnr': '12016-10004039101-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T15:21:07.892',
#   'eintrittsdatum': '2026-03-03',
#   'kundennummerHash': 'QCGqch7PL50CBjk6teuMzDX913ummnZAOsdgVWgX3GY='},
#  {'beruf': 'Helfer/in - Verkauf',
#   'titel': 'Angestellter / Verkäufer m/w/d Kissen und Vorhänge',
#   'refnr': '12016-10004039280-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T14:31:45.581',
#   'eintrittsdatum': '2026-02-28',
#   'kundennummerHash': 'K-odMSiWh6Flr85j5gueeE_9FFhpOtsHIPbrBKoeCCs='},
#  {'beruf': 'Sozialversicherungsfachangestellte/r - knappschaftliche Sozialversicherung',
#   'titel': 'Sozialversicherungsfachangestellter m/w/d',
#   'refnr': '12016-10004039353-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T14:20:49.105',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'K-odMSiWh6Flr85j5gueeE_9FFhpOtsHIPbrBKoeCCs='},
#  {'beruf': 'Auslieferungsfahrer/in (nicht Verkaufsfahrer/in)',
#   'titel': 'Fahrer - Festanstellung - Berliner Raum (m/w/d)',
#   'refnr': '12016-10004041902-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T14:02:10.544',
#   'eintrittsdatum': '2026-03-03',
#   'kundennummerHash': '2vEM2N0NLlEG-XTOdlkJO7u1PwQqDBz6ruvkeOsW_hM='},
#  {'beruf': 'Tischler/in',
#   'titel': 'Tischler',
#   'refnr': '15518-CF62DQAM5F0L6CX4-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'iperdi GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T13:31:10.686',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'UtcRyOB4TiRKhXXNBAjIm7IEGBTA7zRqPQulDmkgtPw='},
#  {'beruf': 'CNC-Dreher/in',
#   'titel': 'CNC-Fräser / CNC-Dreher (m-w-d-x)',
#   'refnr': '15518-V31AL5VJWQR1MLGK-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'iperdi GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T13:31:10.596',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'UtcRyOB4TiRKhXXNBAjIm7IEGBTA7zRqPQulDmkgtPw='},
#  {'beruf': 'Helfer/in - Reinigung',
#   'titel': 'Reinigungspersonal - Grundschule m/w/d',
#   'refnr': '12016-10004038805-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T13:02:01.524',
#   'eintrittsdatum': '2026-03-03',
#   'kundennummerHash': 'QCGqch7PL50CBjk6teuMzDX913ummnZAOsdgVWgX3GY='},
#  {'beruf': 'Helfer/in - Küche',
#   'titel': 'Helfer/in m/w/d- Küche - Krankenhaus',
#   'refnr': '12016-10004038194-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T13:02:01.315',
#   'eintrittsdatum': '2026-03-03',
#   'kundennummerHash': 'QCGqch7PL50CBjk6teuMzDX913ummnZAOsdgVWgX3GY='},
#  {'beruf': 'Zerspanungsmechaniker/in',
#   'titel': 'Zerspanungsmechaniker (m/w/d/x)',
#   'refnr': '15518-SDCTLEWVQX5IOEQB-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'iperdi GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T12:31:59.161',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'UtcRyOB4TiRKhXXNBAjIm7IEGBTA7zRqPQulDmkgtPw='},
#  {'beruf': 'Instandhaltungstechniker/in',
#   'titel': 'Instandhalter',
#   'refnr': '15518-VZM5NOVD5VQ0UERG-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'iperdi GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T12:31:58.969',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'UtcRyOB4TiRKhXXNBAjIm7IEGBTA7zRqPQulDmkgtPw='},
#  {'beruf': 'Fachverkäufer/in - Nahrungsmittel',
#   'titel': 'Kassierer - Supermarkt - Vollzeit/ Teilzeit m/w/d',
#   'refnr': '12016-10004039262-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T12:01:04.723',
#   'eintrittsdatum': '2026-03-03',
#   'kundennummerHash': 'K-odMSiWh6Flr85j5gueeE_9FFhpOtsHIPbrBKoeCCs='},
#  {'beruf': 'Callcenteragent/in',
#   'titel': 'Callcenter Agent (m/w/d/x)',
#   'refnr': '15518-9T9C4FYAHNOXB6RQ-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'iperdi GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T11:30:36.588',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'UtcRyOB4TiRKhXXNBAjIm7IEGBTA7zRqPQulDmkgtPw='},
#  {'beruf': 'Lohn- und Gehaltsbuchhalter/in',
#   'titel': 'Lohnbuchhalter (m-w-d-x)',
#   'refnr': '15518-PJXSW7L0F82QBANK-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'iperdi GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T11:30:36.463',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'UtcRyOB4TiRKhXXNBAjIm7IEGBTA7zRqPQulDmkgtPw='},
#  {'beruf': 'Kaufmann/-frau - Bürokommunikation',
#   'titel': 'Kauffrau für Bürokommunikation (m/w/d) Copy-Shop!',
#   'refnr': '12016-10004039288-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T11:12:13.631',
#   'eintrittsdatum': '2026-03-03',
#   'kundennummerHash': 'K-odMSiWh6Flr85j5gueeE_9FFhpOtsHIPbrBKoeCCs='},
#  {'beruf': 'Klinische/r Psychologe/Psychologin',
#   'titel': 'Geprüfter Psychologe - Einzelfallhilfe (m/w/d)',
#   'refnr': '12016-10004039094-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T11:12:13.485',
#   'eintrittsdatum': '2026-03-02',
#   'kundennummerHash': 'QCGqch7PL50CBjk6teuMzDX913ummnZAOsdgVWgX3GY='},
#  {'beruf': 'Servicekraft - Gastronomie und Gastgewerbe',
#   'titel': 'Servicekraft / Spülkraft (m/w/d) - Für ein türkischen Imbiss',
#   'refnr': '12016-10004039034-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T10:52:20.45',
#   'eintrittsdatum': '2026-03-02',
#   'kundennummerHash': 'QCGqch7PL50CBjk6teuMzDX913ummnZAOsdgVWgX3GY='},
#  {'beruf': 'Verkäufer/in',
#   'titel': 'Verkäufer (m/w/d) Zoofachhandel',
#   'refnr': '12016-10004039235-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T10:41:39.505',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'K-odMSiWh6Flr85j5gueeE_9FFhpOtsHIPbrBKoeCCs='},
#  {'beruf': 'Bodenleger/in',
#   'titel': 'Bodenleger /in - Parkett (m/w/d)',
#   'refnr': '12016-10004042130-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T09:51:51.802',
#   'eintrittsdatum': '2026-02-28',
#   'kundennummerHash': 'Z-HzVkUCLGQiQFxQSAICs302sSdB9Sp7XtgOiO4GGCA='},
#  {'beruf': 'Helfer/in - Reinigung',
#   'titel': 'Reiniger m/w/d - Steakhouse - Attraktive Zuschläge',
#   'refnr': '12016-10004038804-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T09:40:41.704',
#   'eintrittsdatum': '2026-02-28',
#   'kundennummerHash': 'QCGqch7PL50CBjk6teuMzDX913ummnZAOsdgVWgX3GY='},
#  {'beruf': 'Bürokaufmann/-frau',
#   'titel': 'Bürokauffrau /Bürokaufmann  (m-w-d-x)',
#   'refnr': '15518-43XJYI4KLLPI3980-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'iperdi GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T09:30:32.963',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'UtcRyOB4TiRKhXXNBAjIm7IEGBTA7zRqPQulDmkgtPw='},
#  {'beruf': 'Verkäufer/in',
#   'titel': 'Kassierer/in - Autoersatzteile- 13,70€ Stunde',
#   'refnr': '12016-10004039212-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T09:01:01.052',
#   'eintrittsdatum': '2026-03-01',
#   'kundennummerHash': 'K-odMSiWh6Flr85j5gueeE_9FFhpOtsHIPbrBKoeCCs='},
#  {'beruf': 'Dienstwagenfahrer/in',
#   'titel': 'Shuttle-Service - Hotel - Flughafen BER (m/w/d)',
#   'refnr': '12016-10004041833-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T08:42:12.658',
#   'eintrittsdatum': '2026-03-03',
#   'kundennummerHash': '2vEM2N0NLlEG-XTOdlkJO7u1PwQqDBz6ruvkeOsW_hM='},
#  {'beruf': 'Helfer/in - Reinigung',
#   'titel': 'Reinigung - Möbelhaus - 22,86 Euro (m/w/d)',
#   'refnr': '12016-10004038801-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T08:32:54.577',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'QCGqch7PL50CBjk6teuMzDX913ummnZAOsdgVWgX3GY='},
#  {'beruf': 'Verkäufer/in',
#   'titel': 'Verkäufer - Schöneberg - m/w/d',
#   'refnr': '12016-10004039224-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T08:15:03.153',
#   'eintrittsdatum': '2026-03-03',
#   'kundennummerHash': 'K-odMSiWh6Flr85j5gueeE_9FFhpOtsHIPbrBKoeCCs='},
#  {'beruf': 'Betreuungskraft / Alltagsbegleiter/in',
#   'titel': 'Alltagsbegleiter - Klinikum - 40-Stunden - jetzt (m/w/d)',
#   'refnr': '12016-10004043438-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T07:29:30.887',
#   'eintrittsdatum': '2026-02-28',
#   'kundennummerHash': 'Z-HzVkUCLGQiQFxQSAICs302sSdB9Sp7XtgOiO4GGCA='},
#  {'beruf': 'Servicekraft - Schutz und Sicherheit',
#   'titel': 'Mitarbeiter für Berliner Behörden (m/w/d)',
#   'refnr': '12016-10004041983-S',
#   'arbeitsort': {'plz': '10243',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.512790999, 'lon': 13.440177562},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T17:41:19.474',
#   'eintrittsdatum': '2026-02-28',
#   'kundennummerHash': '2vEM2N0NLlEG-XTOdlkJO7u1PwQqDBz6ruvkeOsW_hM='},
#  {'beruf': 'Betreuungskraft / Alltagsbegleiter/in',
#   'titel': 'Betreuungskraft -Ambulante Dienste (m/w/d)',
#   'refnr': '12016-10004038741-S',
#   'arbeitsort': {'plz': '10243',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.512790999, 'lon': 13.440177562},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T17:01:52.225',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'QCGqch7PL50CBjk6teuMzDX913ummnZAOsdgVWgX3GY='},
#  {'beruf': 'Verkäufer/in',
#   'titel': 'Verkäufer (m/w/d) - Berlin-Warschauer Straße',
#   'refnr': '14927-1muvak5zooz-S',
#   'arbeitsort': {'plz': '10243',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.512791, 'lon': 13.4401776},
#    'entfernung': '1'},
#   'arbeitgeber': 'dennree GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T17:01:40.652',
#   'eintrittsdatum': '2026-02-27',
#   'externeUrl': 'https://jobs4us.de/jobad/verkaeufer-berlinwarschauer-strasse_1muvak5zooz'},
#  {'beruf': 'Kommissionierer/in',
#   'titel': 'Packaushilfe (m/w/d) - Berlin-Warschauer Straße',
#   'refnr': '14927-1ciqlzy5uwx-S',
#   'arbeitsort': {'plz': '10243',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.512791, 'lon': 13.4401776},
#    'entfernung': '1'},
#   'arbeitgeber': 'dennree GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T17:01:40.448',
#   'eintrittsdatum': '2026-02-27',
#   'externeUrl': 'https://jobs4us.de/jobad/packaushilfe-berlinwarschauer-strasse_1ciqlzy5uwx'},
#  {'beruf': 'Maschinen- und Anlagenführer/in (ohne Angabe des Schwerpunkts)',
#   'titel': 'Wir suchen Maschinen- und Anlagenführer im Reinraum (m/w/d)',
#   'refnr': '12016-10004041479-S',
#   'arbeitsort': {'plz': '10243',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.512790999, 'lon': 13.440177562},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T15:21:08.329',
#   'eintrittsdatum': '2026-03-01',
#   'kundennummerHash': 'K-odMSiWh6Flr85j5gueeE_9FFhpOtsHIPbrBKoeCCs='},
#  {'beruf': 'Koch/Köchin',
#   'titel': 'Frühstückskoch/Beikoch (m/w/d) für ein Cafe gesucht',
#   'refnr': '12016-10004038256-S',
#   'arbeitsort': {'plz': '10243',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.512790999, 'lon': 13.440177562},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T15:21:07.557',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'QCGqch7PL50CBjk6teuMzDX913ummnZAOsdgVWgX3GY='},
#  {'beruf': 'Stationsleiter/in - Kranken-/Alten-/Kinderkrankenpflege',
#   'titel': 'PFlegefachkraft (m/w/d) Wohngemeinschaft - Spandau',
#   'refnr': '12016-10004043479-S',
#   'arbeitsort': {'plz': '10243',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.512790999, 'lon': 13.440177562},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T13:22:10.755',
#   'eintrittsdatum': '2026-02-28',
#   'kundennummerHash': 'Z-HzVkUCLGQiQFxQSAICs302sSdB9Sp7XtgOiO4GGCA='},
#  {'beruf': 'Verkäufer/in',
#   'titel': 'Verkäufer (m/w/d) Getränkemarkt - Quereinstieg möglich',
#   'refnr': '12016-10004039259-S',
#   'arbeitsort': {'plz': '10243',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.512790999, 'lon': 13.440177562},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T13:11:03.324',
#   'eintrittsdatum': '2026-02-28',
#   'kundennummerHash': 'K-odMSiWh6Flr85j5gueeE_9FFhpOtsHIPbrBKoeCCs='},
#  {'beruf': 'Konditormeister/in/Bachelor Professional im Konditor-Handwerk',
#   'titel': 'Konditormeister (m/w/d)',
#   'refnr': '12016-10004039219-S',
#   'arbeitsort': {'plz': '10243',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.512790999, 'lon': 13.440177562},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T11:30:35.128',
#   'eintrittsdatum': '2026-03-01',
#   'kundennummerHash': 'K-odMSiWh6Flr85j5gueeE_9FFhpOtsHIPbrBKoeCCs='},
#  {'beruf': 'Talent-Acquisition-Manager/in',
#   'titel': '(Senior) Talent Aquisition Manager (all genders)',
#   'refnr': '13635-f6566504_JB5081142-S',
#   'arbeitsort': {'plz': '10243',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.512791, 'lon': 13.4401776},
#    'entfernung': '1'},
#   'arbeitgeber': ']init[ AG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T10:56:09.062',
#   'eintrittsdatum': '2026-02-27',
#   'externeUrl': 'https://www.jobexport.de/job/5081142.html?exp=81&cid=f6566504-4942-4e1a-b4fa-864beaa358c1'},
#  {'beruf': 'Verwaltungswissenschaftler/in',
#   'titel': 'Consultant Public Sector (all genders)',
#   'refnr': '13635-f0c44e93_JB5080628-S',
#   'arbeitsort': {'plz': '10243',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.512791, 'lon': 13.4401776},
#    'entfernung': '1'},
#   'arbeitgeber': ']init[ AG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T10:55:57.391',
#   'eintrittsdatum': '2026-02-27',
#   'externeUrl': 'https://www.jobexport.de/job/5080628.html?exp=81&cid=f0c44e93-447b-41be-82a8-a98eb2d6330c'},
#  {'beruf': 'Verwaltungswissenschaftler/in',
#   'titel': '(Senior) Consultant Public Sector (all genders)',
#   'refnr': '13635-4de5bc8b_JB5080618-S',
#   'arbeitsort': {'plz': '10243',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.512791, 'lon': 13.4401776},
#    'entfernung': '1'},
#   'arbeitgeber': ']init[ AG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T10:55:56.644',
#   'eintrittsdatum': '2026-02-27',
#   'externeUrl': 'https://www.jobexport.de/job/5080618.html?exp=81&cid=4de5bc8b-7cf2-4a19-8f70-66dc6f761f18'},
#  {'beruf': 'Steuerfachangestellte/r',
#   'titel': 'Finanzbuchhalter (m/w/d)',
#   'refnr': '13405-FFNEHFWIGLER2EAV-S',
#   'arbeitsort': {'plz': '10243',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.512790999, 'lon': 13.440177562},
#    'entfernung': '1'},
#   'arbeitgeber': 'EPOS Personaldienstleistungen GmbH Office&Finance Services Berlin',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T09:44:25.731',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'rZjudLWHL-N8WUTXGNEbMoGakj3S3E2tEPCvghEBdKA='},
#  {'beruf': 'Psychologe/Psychologin',
#   'titel': 'Psychologe m/w/d Berliner Klinikum - 2-Schicht',
#   'refnr': '12016-10004039100-S',
#   'arbeitsort': {'plz': '10243',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.512790999, 'lon': 13.440177562},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T08:42:12.508',
#   'eintrittsdatum': '2026-03-02',
#   'kundennummerHash': 'QCGqch7PL50CBjk6teuMzDX913ummnZAOsdgVWgX3GY='},
#  {'beruf': 'Hauswart/in/Haustechniker/in',
#   'titel': 'Hauswart - Objekt- und Sicherheitskontrollen (m/w/d)',
#   'refnr': '12016-10004041936-S',
#   'arbeitsort': {'plz': '10243',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.512790999, 'lon': 13.440177562},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T07:29:30.438',
#   'eintrittsdatum': '2026-02-28',
#   'kundennummerHash': '2vEM2N0NLlEG-XTOdlkJO7u1PwQqDBz6ruvkeOsW_hM='},
#  {'beruf': 'Ingenieur/in - Versorgungstechnik',
#   'titel': 'Ingenieur:in Versorgungstechnik / TGA (w/m/d)',
#   'refnr': '12288-4736327068-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.5132279, 'lon': 13.4157237},
#    'entfernung': '1'},
#   'arbeitgeber': 'Berliner Wasserbetriebe',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-26',
#   'modifikationsTimestamp': '2026-02-26T18:06:29.031',
#   'eintrittsdatum': '2026-02-27',
#   'externeUrl': 'https://www.persy.jobs/persy/l/job-idope-b'},
#  {'beruf': 'Bürokaufmann/-frau',
#   'titel': 'Verwaltungskraft m/w/d Öffentlicher Dienst',
#   'refnr': '12016-10004031336-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-26',
#   'modifikationsTimestamp': '2026-02-26T17:00:58.051',
#   'eintrittsdatum': '2026-02-26',
#   'kundennummerHash': 'K-odMSiWh6Flr85j5gueeE_9FFhpOtsHIPbrBKoeCCs='},
#  {'beruf': 'Bauelektriker/in',
#   'titel': 'Elektriker (m/w/d) mit Wohnsitz in Berlin, Brandenburg gesucht',
#   'refnr': '10001-1002675764-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'WS Personaldienstleistungen GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-26',
#   'modifikationsTimestamp': '2026-02-26T16:54:59.773',
#   'eintrittsdatum': '2026-02-26',
#   'kundennummerHash': 'cuODUFOAojcTYohvbhqcjVm3E8A3NaJTC6JTspy1LsQ='},
#  {'beruf': 'Maler/in und Lackierer/in - Maler/in',
#   'titel': 'Maler und Lackierer (m/w/d) gesucht',
#   'refnr': '10001-1002675696-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'WS Personaldienstleistungen GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-26',
#   'modifikationsTimestamp': '2026-02-26T16:46:10.419',
#   'eintrittsdatum': '2026-02-26',
#   'kundennummerHash': 'cuODUFOAojcTYohvbhqcjVm3E8A3NaJTC6JTspy1LsQ='},
#  {'beruf': 'Bauklempner/in',
#   'titel': 'Bauklempner /in - Klempner (m/w/d)',
#   'refnr': '12016-10004036544-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-26',
#   'modifikationsTimestamp': '2026-02-26T15:21:06.126',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'Z-HzVkUCLGQiQFxQSAICs302sSdB9Sp7XtgOiO4GGCA='},
#  {'beruf': 'Maschinen- und Anlagenführer/in (ohne Angabe des Schwerpunkts)',
#   'titel': 'Maschinenführer/in - Produktion - super Gehalt!',
#   'refnr': '12016-10004033498-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-26',
#   'modifikationsTimestamp': '2026-02-26T15:21:04.984',
#   'eintrittsdatum': '2026-03-02',
#   'kundennummerHash': '2vEM2N0NLlEG-XTOdlkJO7u1PwQqDBz6ruvkeOsW_hM='},
#  {'beruf': 'Lager- und Transportarbeiter/in',
#   'titel': 'Lagerkraft (m/w/d) - Festvertrag - 17,12 EUR/Std. Tiefkühllager',
#   'refnr': '12016-10004033313-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-26',
#   'modifikationsTimestamp': '2026-02-26T15:21:04.762',
#   'eintrittsdatum': '2026-03-02',
#   'kundennummerHash': 'K-odMSiWh6Flr85j5gueeE_9FFhpOtsHIPbrBKoeCCs='},
#  {'beruf': 'Betreuungskraft / Alltagsbegleiter/in',
#   'titel': 'Betreuungskraft / Sozialassistent (m/w/d)',
#   'refnr': '12016-10004035047-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-26',
#   'modifikationsTimestamp': '2026-02-26T14:51:45.527',
#   'eintrittsdatum': '2026-03-01',
#   'kundennummerHash': 'Z-HzVkUCLGQiQFxQSAICs302sSdB9Sp7XtgOiO4GGCA='},
#  {'beruf': 'Pflegeassistent/in',
#   'titel': 'Pflegeassistent /in',
#   'refnr': '12016-10004030577-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-26',
#   'modifikationsTimestamp': '2026-02-26T14:51:45.062',
#   'eintrittsdatum': '2026-02-28',
#   'kundennummerHash': 'QCGqch7PL50CBjk6teuMzDX913ummnZAOsdgVWgX3GY='},
#  {'beruf': 'Berufskraftfahrer/in',
#   'titel': 'Baumaschinen - Minibagger - C / CE - Kraftfahrer (m/w/d)',
#   'refnr': '12016-10004033458-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-26',
#   'modifikationsTimestamp': '2026-02-26T14:33:13.188',
#   'eintrittsdatum': '2026-02-28',
#   'kundennummerHash': '2vEM2N0NLlEG-XTOdlkJO7u1PwQqDBz6ruvkeOsW_hM='},
#  {'beruf': 'Schichtführer/in',
#   'titel': 'Vorarbeiter/in - Büroreinigung - Festvertrag *',
#   'refnr': '12016-10004030771-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-26',
#   'modifikationsTimestamp': '2026-02-26T14:10:53.666',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'QCGqch7PL50CBjk6teuMzDX913ummnZAOsdgVWgX3GY='},
#  {'beruf': 'Bauelektriker/in',
#   'titel': 'Elektriker (m/w/d) mit Wohnsitz in Berlin, Brandenburg gesucht',
#   'refnr': '10001-1002673722-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'WS Personaldienstleistungen GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-26',
#   'modifikationsTimestamp': '2026-02-26T13:53:33.78',
#   'eintrittsdatum': '2026-02-26',
#   'kundennummerHash': 'cuODUFOAojcTYohvbhqcjVm3E8A3NaJTC6JTspy1LsQ='},
#  {'beruf': 'Pädagoge/Pädagogin',
#   'titel': 'Pädagoge - Evangelische Schule - Vollzeit m/w/d',
#   'refnr': '12016-10004031151-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-26',
#   'modifikationsTimestamp': '2026-02-26T13:41:56.576',
#   'eintrittsdatum': '2026-02-28',
#   'kundennummerHash': 'QCGqch7PL50CBjk6teuMzDX913ummnZAOsdgVWgX3GY='},
#  {'beruf': 'Berufskraftfahrer/in',
#   'titel': 'Kurierdienstfahrer - Vollzeit - Neukölln (m/w/d)',
#   'refnr': '12016-10004033419-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-26',
#   'modifikationsTimestamp': '2026-02-26T12:01:16.299',
#   'eintrittsdatum': '2026-03-02',
#   'kundennummerHash': '2vEM2N0NLlEG-XTOdlkJO7u1PwQqDBz6ruvkeOsW_hM='},
#  {'beruf': 'Maler/in und Lackierer/in - Maler/in',
#   'titel': 'Maler und Lackierer (m/w/d) gesucht',
#   'refnr': '10001-1002671415-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'WS Personaldienstleistungen GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-26',
#   'modifikationsTimestamp': '2026-02-26T11:18:03.77',
#   'eintrittsdatum': '2026-02-26',
#   'kundennummerHash': 'cuODUFOAojcTYohvbhqcjVm3E8A3NaJTC6JTspy1LsQ='},
#  {'beruf': 'Helfer/in - Küche',
#   'titel': 'Helfer / Küchenkraft (m/w/d) - Kindergarten - Teilzeit',
#   'refnr': '12016-10004035488-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-26',
#   'modifikationsTimestamp': '2026-02-26T10:51:42.95',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'Z-HzVkUCLGQiQFxQSAICs302sSdB9Sp7XtgOiO4GGCA='},
#  {'beruf': 'Außenhandelsassistent/in',
#   'titel': 'Außenhandelsassistent  (m/w/d)',
#   'refnr': '12016-10004031531-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-26',
#   'modifikationsTimestamp': '2026-02-26T10:11:34.547',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'K-odMSiWh6Flr85j5gueeE_9FFhpOtsHIPbrBKoeCCs='},
#  {'beruf': 'Verkäufer/in',
#   'titel': 'Verkäufer - Gartenmöbel (m/w/d)',
#   'refnr': '12016-10004035200-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-26',
#   'modifikationsTimestamp': '2026-02-26T10:01:20.318',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'Z-HzVkUCLGQiQFxQSAICs302sSdB9Sp7XtgOiO4GGCA='},
#  {'beruf': 'Buchhalter/in',
#   'titel': 'Steuerberater (m/w/d) ',
#   'refnr': '16204-0063112914-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'DBB DATA Steuerberatung GmbH DBB DATA Steuerberatung GmbH DBB DATA Steuerberatung GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-26',
#   'modifikationsTimestamp': '2026-02-26T09:32:22.892',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'Q-4U1lVB13oQ6Gpc0yqoZCIPOGLefANXlnMo5dJ0vXc='},
#  {'beruf': 'Steuerfachangestellte/r',
#   'titel': 'Steuerfachangestellte/Bilanzbuchhalter (m/w/d) Vollzeit/Teilzeit',
#   'refnr': '16204-0063112394-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'DBB DATA Steuerberatung GmbH DBB DATA Steuerberatung GmbH DBB DATA Steuerberatung GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-26',
#   'modifikationsTimestamp': '2026-02-26T09:12:46.756',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'Q-4U1lVB13oQ6Gpc0yqoZCIPOGLefANXlnMo5dJ0vXc='},
#  {'beruf': 'Fachverkäufer/in - Lebensmittelhandwerk (Fleischerei)',
#   'titel': 'Fleisch- und Wurstverkäufer m/w/d *Gute Vergütung',
#   'refnr': '12016-10004035180-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.513227933001, 'lon': 13.415723718},
#    'entfernung': '1'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-26',
#   'modifikationsTimestamp': '2026-02-26T09:01:17.385',
#   'eintrittsdatum': '2026-03-01',
#   'kundennummerHash': 'Z-HzVkUCLGQiQFxQSAICs302sSdB9Sp7XtgOiO4GGCA='},
#  {'beruf': 'Softwareentwickler/in',
#   'titel': 'Junior Frontend Software Engineer: Inbound engineering (all genders)',
#   'refnr': '18251-28662-S',
#   'arbeitsort': {'plz': '10243',
#    'ort': 'Berlin',
#    'strasse': 'Valeska-Gert-Straße 5',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.506468, 'lon': 13.441248},
#    'entfernung': '1'},
#   'arbeitgeber': 'Zalando SE',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T08:20:27.206',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': '6j1LD7GT5Ptmu4Kjh_aAXrzBy8l2iE9iGSfd_WjRWHc='},
#  {'beruf': 'Business-Analyst/in',
#   'titel': 'Senior Manager Financial Reporting - Group Reporting (all genders)',
#   'refnr': '18251-28583-S',
#   'arbeitsort': {'plz': '10243',
#    'ort': 'Berlin',
#    'strasse': 'Valeska-Gert-Straße 5',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.506468, 'lon': 13.441248},
#    'entfernung': '1'},
#   'arbeitgeber': 'Zalando SE',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T08:20:26.91',
#   'eintrittsdatum': '2026-04-01',
#   'kundennummerHash': '6j1LD7GT5Ptmu4Kjh_aAXrzBy8l2iE9iGSfd_WjRWHc='},
#  {'beruf': 'Fachberater/in - Vertrieb',
#   'titel': 'Teamleiter Vertrieb (m/w/d)',
#   'refnr': '12122-1004141-1755950-0-S',
#   'arbeitsort': {'plz': '10179',
#    'ort': 'Berlin',
#    'strasse': 'Brückenstr. 5-6a',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.512633, 'lon': 13.41747},
#    'entfernung': '1'},
#   'arbeitgeber': 'persona service AG & Co. KG Berlin-Mitte',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-25',
#   'modifikationsTimestamp': '2026-02-26T11:15:40.518',
#   'eintrittsdatum': '2026-03-09',
#   'kundennummerHash': 'ulLm11xcbKrgOf6O5rIdxb5B5ymdj1a-NIVQQcsEEis='},
#  {'beruf': 'Kontokorrentbuchhalter/in',
#   'titel': 'ID: 16094 - Debitorenbuchhalter (m/w/d)',
#   'refnr': '12288-4736971511-S',
# ...
#   'eintrittsdatum': '2026-03-02',
#   'kundennummerHash': 'QCGqch7PL50CBjk6teuMzDX913ummnZAOsdgVWgX3GY='},
#  {'beruf': 'Personalsachbearbeiter/in',
#   'titel': 'Personalsachbearbeiter (m/w/d)',
#   'refnr': '12254-2-223238-S',
#   'arbeitsort': {'plz': '10249',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.523643977, 'lon': 13.445373265},
#    'entfernung': '2'},
#   'arbeitgeber': 'RADAS Jobbörse & Personalvermittlung GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T07:29:34.661',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'TTF_DeKkMG9KR-6RVFatw4P9m8_PbK7Z8_7y7O9nXjQ='},
#  {'beruf': 'Callcenteragent/in',
#   'titel': 'Kundenbetreuer (m/w/d) ab jetzt',
#   'refnr': '12254-2-223225-S',
#   'arbeitsort': {'plz': '10249',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.523643977, 'lon': 13.445373265},
#    'entfernung': '2'},
#   'arbeitgeber': 'RADAS Jobbörse & Personalvermittlung GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T07:29:34.304',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'TTF_DeKkMG9KR-6RVFatw4P9m8_PbK7Z8_7y7O9nXjQ='},
#  {'beruf': 'Callcenteragent/in',
#   'titel': 'Kundenbetreuer (m/w/d)',
#   'refnr': '12254-2-223224-S',
#   'arbeitsort': {'plz': '10249',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.523643977, 'lon': 13.445373265},
#    'entfernung': '2'},
#   'arbeitgeber': 'RADAS Jobbörse & Personalvermittlung GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T07:29:34.243',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'TTF_DeKkMG9KR-6RVFatw4P9m8_PbK7Z8_7y7O9nXjQ='},
#  {'beruf': 'Empfangskraft',
#   'titel': 'Rezeptionist (m/w/d) in Direktvermittlung',
#   'refnr': '12254-3-223211-S',
#   'arbeitsort': {'plz': '10249',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.523643977, 'lon': 13.445373265},
#    'entfernung': '2'},
#   'arbeitgeber': 'RADAS Jobbörse & Personalvermittlung GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T07:29:33.959',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'TTF_DeKkMG9KR-6RVFatw4P9m8_PbK7Z8_7y7O9nXjQ='},
#  {'beruf': 'Altenpfleger/in',
#   'titel': 'Altenpfleger (m/w/d) für Berlin',
#   'refnr': '12254-3-223210-S',
#   'arbeitsort': {'plz': '10249',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.523643977, 'lon': 13.445373265},
#    'entfernung': '2'},
#   'arbeitgeber': 'RADAS Jobbörse & Personalvermittlung GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T07:29:33.9',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'TTF_DeKkMG9KR-6RVFatw4P9m8_PbK7Z8_7y7O9nXjQ='},
#  {'beruf': 'Kaufmännische Fachkraft',
#   'titel': 'Bürokraft (m/w/d) dringend gesucht',
#   'refnr': '12254-2-223192-S',
#   'arbeitsort': {'plz': '10249',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.523643977, 'lon': 13.445373265},
#    'entfernung': '2'},
#   'arbeitgeber': 'RADAS Jobbörse & Personalvermittlung GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T07:29:33.389',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'TTF_DeKkMG9KR-6RVFatw4P9m8_PbK7Z8_7y7O9nXjQ='},
#  {'beruf': 'Geflügelfleischer/in',
#   'titel': 'Fleischer (m/w/d) - Gesundbrunnen - Vollzeit',
#   'refnr': '12016-10004041482-S',
#   'arbeitsort': {'plz': '10249',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.523643977, 'lon': 13.445373265},
#    'entfernung': '2'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T07:29:29.937',
#   'eintrittsdatum': '2026-03-03',
#   'kundennummerHash': 'K-odMSiWh6Flr85j5gueeE_9FFhpOtsHIPbrBKoeCCs='},
#  {'beruf': 'Verkäufer/in',
#   'titel': 'Verkäufer (m/w/d) - Berlin-Mühsamstraße',
#   'refnr': '14927-1nrs6ztaip7-S',
#   'arbeitsort': {'plz': '10249',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.523644, 'lon': 13.4453733},
#    'entfernung': '2'},
#   'arbeitgeber': 'dennree GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T17:01:40.515',
#   'eintrittsdatum': '2026-02-27',
#   'externeUrl': 'https://jobs4us.de/jobad/verkaeufer-berlinmuehsamstrasse_1nrs6ztaip7'},
#  {'beruf': 'Filialleiter/in, Verkaufsstellenleiter/in',
#   'titel': 'Marktleitung (m/w/d) - Berlin-Mühsamstraße',
#   'refnr': '14927-1jr5fz1jg3s-S',
#   'arbeitsort': {'plz': '10249',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.523644, 'lon': 13.4453733},
#    'entfernung': '2'},
#   'arbeitgeber': 'dennree GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T17:01:40.313',
#   'eintrittsdatum': '2026-02-27',
#   'externeUrl': 'https://jobs4us.de/jobad/marktleitung-berlinmuehsamstrasse_1jr5fz1jg3s'},
#  {'beruf': 'Medizinische/r Technologe/Technologin - Laboratoriumsanalytik',
#   'titel': 'MTLA (m/w/d) Direktvermittlung- Friedrichshain ',
#   'refnr': '14087-8SXIS4QI8IPTWH6O-S',
#   'arbeitsort': {'plz': '10249',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.523644, 'lon': 13.4453733},
#    'entfernung': '2'},
#   'arbeitgeber': 'Perso Plankontor GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T08:35:00.27',
#   'eintrittsdatum': '2026-02-27',
#   'externeUrl': 'https://www.europersonal.com/stelle/mtla-m-w-d-direktvermittlung-friedrichshain-af2a6c8f7a124f0b9a810d670458ce32'},
#  {'beruf': 'Softwareentwickler/in',
#   'titel': 'ID: 16065 - .NET-Entwickler (m/w/d)',
#   'refnr': '12288-4737007489-S',
#   'arbeitsort': {'plz': '10969',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.5020486, 'lon': 13.4014463},
#    'entfernung': '2'},
#   'arbeitgeber': 'SkyHire GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T18:09:44.539',
#   'eintrittsdatum': '2026-02-28',
#   'externeUrl': 'https://www.persy.jobs/persy/l/job-idv5k-b'},
#  {'beruf': 'Fachkaufmann/-frau - Verwaltung von Wohnungseigentum',
#   'titel': 'Immobilienverwalter (m/w/d) WEG - Direktvermittlung',
#   'refnr': '12288-4737014882-S',
#   'arbeitsort': {'plz': '10969',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.5020486, 'lon': 13.4014463},
#    'entfernung': '2'},
#   'arbeitgeber': 'MANAWA Consulting GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T18:09:38.067',
#   'eintrittsdatum': '2026-02-28',
#   'externeUrl': 'https://www.persy.jobs/persy/l/job-idv87-b'},
#  {'beruf': 'Requirement-Manager/in',
#   'titel': 'Requirements Engineer (m/w/d) - Direktvermittlung',
#   'refnr': '12288-4737015778-S',
#   'arbeitsort': {'plz': '10969',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.5020486, 'lon': 13.4014463},
#    'entfernung': '2'},
#   'arbeitgeber': 'MANAWA Consulting GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T18:09:37.206',
#   'eintrittsdatum': '2026-02-28',
#   'externeUrl': 'https://www.persy.jobs/persy/l/job-idv8k-b'},
#  {'beruf': 'Buchhalter/in',
#   'titel': 'WEG-Buchhalter (m/w/d)',
#   'refnr': '12288-4736975919-S',
#   'arbeitsort': {'plz': '10969',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.5020486, 'lon': 13.4014463},
#    'entfernung': '2'},
#   'arbeitgeber': 'MANAWA Consulting GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T18:07:24.778',
#   'eintrittsdatum': '2026-02-28',
#   'externeUrl': 'https://www.persy.jobs/persy/l/job-iduu5-b'},
#  {'beruf': 'Betriebswirt/in (Fachschule) - Steuern/Bachelor Professional in Wirtschaft',
#   'titel': 'Sachbearbeiter:in Steuern und Finanzen im Team Haushalt und Finanzen',
#   'refnr': '14089-01420176-S',
#   'arbeitsort': {'plz': '10969',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.5020486, 'lon': 13.4014463},
#    'entfernung': '2'},
#   'arbeitgeber': 'Verbraucherzentrale Bundesverband e.V.',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T17:34:42.871',
#   'eintrittsdatum': '2026-02-27',
#   'externeUrl': 'https://www.interamt.de/koop/app/stelle?id=1420176'},
#  {'beruf': 'Informatiker/in',
#   'titel': 'Junior SOC Analyst (m/f/d)',
#   'refnr': '13635-3f9b25af_JB5080871-S',
#   'arbeitsort': {'plz': '10969',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.5020486, 'lon': 13.4014463},
#    'entfernung': '2'},
#   'arbeitgeber': 'Smartbroker AG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T10:56:03.026',
#   'eintrittsdatum': '2026-02-27',
#   'externeUrl': 'https://www.jobexport.de/job/5080871.html?exp=81&cid=3f9b25af-ada1-402d-81f5-3ed88148a179'},
#  {'beruf': 'Callcenteragent/in',
#   'titel': 'Telefonischer Kundenberater m/w/d - Annahme von Bestellungen',
#   'refnr': '12016-10004043516-S',
#   'arbeitsort': {'plz': '10969',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.502048591, 'lon': 13.401446278},
#    'entfernung': '2'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T17:41:19.678',
#   'eintrittsdatum': '2026-02-28',
#   'kundennummerHash': 'Z-HzVkUCLGQiQFxQSAICs302sSdB9Sp7XtgOiO4GGCA='},
#  {'beruf': 'Physiotherapeut/in',
#   'titel': 'Wir suchen &gt; Physiotherapeut (m/w/d) Berliner Praxis',
#   'refnr': '12016-10004039093-S',
#   'arbeitsort': {'plz': '10969',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.502048591, 'lon': 13.401446278},
#    'entfernung': '2'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T14:31:45.496',
#   'eintrittsdatum': '2026-03-01',
#   'kundennummerHash': 'QCGqch7PL50CBjk6teuMzDX913ummnZAOsdgVWgX3GY='},
#  {'beruf': 'Helfer/in - Küche',
#   'titel': 'Servicekraft gesucht: für eine Jugendherberge (m/w/d)',
#   'refnr': '12016-10004039036-S',
#   'arbeitsort': {'plz': '10969',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.502048591, 'lon': 13.401446278},
#    'entfernung': '2'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T14:11:23.944',
#   'eintrittsdatum': '2026-03-02',
#   'kundennummerHash': 'QCGqch7PL50CBjk6teuMzDX913ummnZAOsdgVWgX3GY='},
#  {'beruf': 'Kassierer/in (Handel)',
#   'titel': 'Fachverkäuferin (m/w/d) - Baumaschinen - FESTVERTRAG!',
#   'refnr': '12016-10004039223-S',
#   'arbeitsort': {'plz': '10969',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.502048591, 'lon': 13.401446278},
#    'entfernung': '2'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T14:02:10.424',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'K-odMSiWh6Flr85j5gueeE_9FFhpOtsHIPbrBKoeCCs='},
#  {'beruf': 'Bautischler/in',
#   'titel': 'Bautischler (m/w/d) + 800 € Prämie',
#   'refnr': '10001-1002681872-S',
#   'arbeitsort': {'plz': '10969',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.502048591, 'lon': 13.401446278},
#    'entfernung': '2'},
#   'arbeitgeber': 'Akzent Personaldienstleistungen Mitte GmbH',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T13:48:39.486',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': '6G3YiHjDJY8gv0SR-ATpm2YvuNhQmj6s8Iict-aX4tA='},
#  {'beruf': 'Ausbaufacharbeiter/in - Fliesen-, Platten- und Mosaikarbeiten',
#   'titel': 'Fliesenleger /in und Trocknungstechniker mwd',
#   'refnr': '12016-10004042143-S',
#   'arbeitsort': {'plz': '10969',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.502048591, 'lon': 13.401446278},
#    'entfernung': '2'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T12:51:30.948',
#   'eintrittsdatum': '2026-03-02',
#   'kundennummerHash': 'Z-HzVkUCLGQiQFxQSAICs302sSdB9Sp7XtgOiO4GGCA='},
#  {'beruf': 'Helfer/in - Hochbau',
#   'titel': 'Gesucht Bauhelfer (m/w/d) Ein- und  Mehrfamilienhäuser',
#   'refnr': '12016-10004042118-S',
#   'arbeitsort': {'plz': '10969',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.502048591, 'lon': 13.401446278},
#    'entfernung': '2'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T10:41:39.745',
#   'eintrittsdatum': '2026-02-28',
#   'kundennummerHash': 'Z-HzVkUCLGQiQFxQSAICs302sSdB9Sp7XtgOiO4GGCA='},
#  {'beruf': 'Ergotherapeut/in',
#   'titel': 'Ergotherapeutin (m/w/d) - für orthopädische Praxis gesucht!',
#   'refnr': '12016-10004038779-S',
#   'arbeitsort': {'plz': '10969',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.502048591, 'lon': 13.401446278},
#    'entfernung': '2'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T10:41:39.339',
#   'eintrittsdatum': '2026-02-27',
#   'kundennummerHash': 'QCGqch7PL50CBjk6teuMzDX913ummnZAOsdgVWgX3GY='},
#  {'beruf': 'Sozialarbeiter/in / Sozialpädagoge/-pädagogin',
#   'titel': 'Diplom-Sozialarbeiter – Klinikum – VZ – ab sofort (m/w/d)',
#   'refnr': '12016-10004039124-S',
#   'arbeitsort': {'plz': '10969',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.502048591, 'lon': 13.401446278},
#    'entfernung': '2'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T09:51:51.582',
#   'eintrittsdatum': '2026-03-02',
#   'kundennummerHash': 'QCGqch7PL50CBjk6teuMzDX913ummnZAOsdgVWgX3GY='},
#  {'beruf': 'Verkäufer/in',
#   'titel': 'Helfer im Verkauf - SB-Bäckerei - Vollzeit (m/w/d)',
#   'refnr': '12016-10004039214-S',
#   'arbeitsort': {'plz': '10969',
#    'ort': 'Berlin',
#    'strasse': 'null',
#    'region': 'Berlin',
#    'land': 'Deutschland',
#    'koordinaten': {'lat': 52.502048591, 'lon': 13.401446278},
#    'entfernung': '2'},
#   'arbeitgeber': 'PerZukunft Arbeitsvermittlung GmbH&Co.KG',
#   'aktuelleVeroeffentlichungsdatum': '2026-02-27',
#   'modifikationsTimestamp': '2026-02-27T09:32:26.04',
#   'eintrittsdatum': '2026-02-28',
#   'kundennummerHash': 'K-odMSiWh6Flr85j5gueeE_9FFhpOtsHIPbrBKoeCCs='}]

# %%
df = json_normalize(jobs)
#df

# %%
df = df[["beruf",	"titel",	"refnr",	"arbeitgeber",	"aktuelleVeroeffentlichungsdatum",	"modifikationsTimestamp",	"eintrittsdatum",	"arbeitsort.plz",	"arbeitsort.ort",	"arbeitsort.strasse",	"arbeitsort.region",	"arbeitsort.land",	"arbeitsort.koordinaten.lat",	"arbeitsort.koordinaten.lon",	"arbeitsort.ortsteil",	"externeUrl"]]
#df

# %%
all_jobs = []

for page in range(1, 41):  # immer Seite 1 als Minimum haben - geht aber auch Seite 41 bis 81
    query["page"] = page   #oben habe ich size 250 gesetzt, daher kriegt man 250 x Seitenanzahl an Ergebnissen
    url = f"{base}?{up.urlencode(query, safe=';')}"  #250 x 40 = 10000
    
    r = requests.get(url, headers=headers, timeout=30)
    data = r.json()
    
    all_jobs.extend(data["stellenangebote"])

df = json_normalize(all_jobs) #erzeugt die Spaltenform die man unten sehen kann
df = df[["beruf",	#alle Spalten die man in der Rückgabe haben will - habe zB die Hashs der spezifischen Personen 
         "titel",	#mal rausgenommen, da wir damit denke eh nichts machen werden
         "refnr",	
         "arbeitgeber",	
         "aktuelleVeroeffentlichungsdatum",	
         "modifikationsTimestamp",	
         "eintrittsdatum",	
         "arbeitsort.plz",	
         "arbeitsort.ort",	
         "arbeitsort.strasse",	
         "arbeitsort.region",	
         "arbeitsort.land",	
         "arbeitsort.koordinaten.lat",	
         "arbeitsort.koordinaten.lon",	
         "arbeitsort.ortsteil",	
         "externeUrl"]]
df
# Out:
#                                               beruf  \
# 0           Fachinformatiker/in - Systemintegration
# 1           Fachinformatiker/in - Systemintegration
# 2                               IT-Administrator/in
# 3           Fachinformatiker/in - Systemintegration
# 4                                       Koch/Köchin
# ...                                             ...
# 9995                             Kommissionierer/in
# 9996                                    Erzieher/in
# 9997               Praxisanleiter/in - Pflegeberufe
# 9998                        Wirtschaftsingenieur/in
# 9999  Sozialarbeiter/in / Sozialpädagoge/-pädagogin
#
#                                                   titel                refnr  \
# 0            Fachinformatiker Systemintegration (m/w/d)   10001-1002668920-S
# 1                       Junior IT-Administrator (m/w/d)   10001-1002668890-S
# 2                              IT-Administrator (m/w/d)   10001-1002668867-S
# 3                       Senior IT-ADMINISTRATOR (m/w/d)   10001-1002668843-S
# 4           Commis de Cuisine (d/w/m) Vollaziet - 12727   10001-1002678734-S
# ...                                                 ...                  ...
# 9995                            Kommissionierer (m/w/d)    11852-928976524-S
# 9996  Erzieher für intensivpädagogische Wohngruppe (...  14413-k27218.2999-S
# 9997                      freigestellte Praxisanleitung   18213-93i6bk85pl-S
# 9998  Bau-/Projektkaufmann/frau - Betriebswirtin (Ho...   10001-1002578011-S
# 9999  Sozialpädagogen/-in / Erzieher/-in (m/w/d) für...   10001-1002368985-S
#
#                                             arbeitgeber  \
# 0                                         NConsult GmbH
# 1                                         NConsult GmbH
# 2                                         NConsult GmbH
# 3                                         NConsult GmbH
# 4                                 SV (Deutschland) GmbH
# ...                                                 ...
# 9995                TimePartner Personalmanagement GmbH
# 9996  KJHV/KJSH-Stiftung Kinder- u. Jugendhilfe-Verb...
# 9997             Victor's Consulting & Verwaltungs GmbH
# 9998  TECHDATA Projektsteuerung und Projekt- managem...
# 9999  "Die Arche" Kinderstiftung Christliches Kinder...
#
#      aktuelleVeroeffentlichungsdatum   modifikationsTimestamp eintrittsdatum  \
# 0                         2026-02-26  2026-02-26T08:51:46.333     2026-02-26
# 1                         2026-02-26  2026-02-26T08:49:38.098     2026-02-26
# 2                         2026-02-26  2026-02-26T08:47:45.586     2026-02-26
# 3                         2026-02-26  2026-02-26T08:45:43.656     2026-02-26
# 4                         2026-02-27  2026-02-27T10:23:46.076     2026-02-27
# ...                              ...                      ...            ...
# 9995                      2026-02-26  2026-02-26T16:55:26.173     2026-02-26
# 9996                      2026-02-26  2026-02-26T10:35:17.065     2026-03-01
# 9997                      2025-11-21    2026-02-23T18:05:10.1     2026-02-23
# 9998                      2026-02-10  2026-02-27T16:17:11.336     2026-02-27
# 9999                      2026-01-06  2026-02-11T09:10:12.936     2026-03-16
#
#      arbeitsort.plz arbeitsort.ort         arbeitsort.strasse  \
# 0               NaN         Berlin                       null
# 1               NaN         Berlin                       null
# 2               NaN         Berlin                       null
# 3               NaN         Berlin                       null
# 4             10243         Berlin  An der Schillingsbrücke 2
# ...             ...            ...                        ...
# 9995          12685         Berlin                       null
# 9996          12685         Berlin                       null
# 9997          10249         Berlin                       null
# 9998          10963         Berlin           Obentrautstr. 72
# 9999          10249         Berlin            Mühsamstraße 74
#
#      arbeitsort.region arbeitsort.land  arbeitsort.koordinaten.lat  \
# 0               Berlin     Deutschland                   52.511261
# 1               Berlin     Deutschland                   52.511261
# 2               Berlin     Deutschland                   52.511261
# 3               Berlin     Deutschland                   52.511261
# 4               Berlin     Deutschland                   52.509861
# ...                ...             ...                         ...
# 9995            Berlin     Deutschland                   52.540295
# 9996            Berlin     Deutschland                   52.540295
# 9997            Berlin     Deutschland                   52.523644
# 9998            Berlin     Deutschland                   52.497443
# 9999            Berlin     Deutschland                   52.521039
#
#       arbeitsort.koordinaten.lon arbeitsort.ortsteil externeUrl
# 0                      13.425515                 NaN        NaN
# 1                      13.425515                 NaN        NaN
# 2                      13.425515                 NaN        NaN
# 3                      13.425515                 NaN        NaN
# 4                      13.429593                 NaN        NaN
# ...                          ...                 ...        ...
# 9995                   13.560921                 NaN        NaN
# 9996                   13.560921                 NaN        NaN
# 9997                   13.445373                 NaN        NaN
# 9998                   13.380419                 NaN        NaN
# 9999                   13.454496      Friedrichshain        NaN
#
# [10000 rows x 16 columns]

# %%
df.to_csv("jobs.csv", index=False) #erzeugt eine Datei mit dem Inhalt der in der Anfrage hierdrüber erhaltenen Werte
                                   #das passiert in dem Verzeichnis wo das Jupyter-Notebook geöffnet ist, falls ihr mal nicht wisst wo es gelandet ist
