# %%
import requests
import urllib.parse as up
import pandas as pd
from pandas import json_normalize
import json
import glob
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
from sklearn.linear_model import LinearRegression
from dash import Dash, html, dcc, callback, Output, Input
import plotly.express as px
import dash_ag_grid as dag
import plotly.graph_objects as go

# %%
df_m_PM10 = pd.read_csv("monthly_avg_deutschland_PM10.csv")
df_m_PM25 = pd.read_csv("monthly_avg_deutschland_PM2,5.csv")
df_m_NO2 = pd.read_csv("monthly_avg_deutschland_NO2.csv")

data = {
    "monthly avg PM<sub>10</sub>  ": df_m_PM10,
    "monthly avg PM<sub>2.5</sub>": df_m_PM25,
    "mothly avg NO<sub>2</sub>": df_m_NO2
}


for df in data.values():
    df["date start"] = pd.to_datetime(df["date start"])

app = Dash(__name__)

app.layout = html.Div([
    html.H1("Air Pollution Dashboard Germany"),
    dcc.Graph(id="pollution-plot")
])


@app.callback(
    Output("pollution-plot", "figure"),
    Input("pollution-plot", "relayoutData")
)
def update_plot(relayoutData):

    fig = go.Figure()

    for name, df in data.items():

        filtered = df

        if relayoutData and "xaxis.range[0]" in relayoutData:

            start = relayoutData["xaxis.range[0]"]
            end = relayoutData["xaxis.range[1]"]

            filtered = df[
                (df["date start"] >= start) &
                (df["date start"] <= end)
            ]

        fig.add_trace(
            go.Bar(
                x=filtered["date start"],
                y=filtered["value"],
                name=name
            )
        )

        if len(filtered) > 3:

            x_num = filtered["date start"].map(pd.Timestamp.toordinal)
            y = filtered["value"]

            coeff = np.polyfit(x_num, y, 3)
            poly = np.poly1d(coeff)

            fig.add_trace(
                go.Scatter(
                    x=filtered["date start"],
                    y=poly(x_num),
                    mode="lines",
                    name=name + " trend"
                )
            )

    fig.update_layout(
        title="Air Pollution Germany",
        xaxis_title="Date",
        yaxis_title="Concentration in µg/m³",
        hovermode="closest"
    )

    return fig


if __name__ == "__main__":
    app.run(debug=True)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 81
#      77     return fig
#      80 if __name__ == "__main__":
# ---> 81     app.run(debug=True)
#
# File ~\.virtualenvs\arxiv_tutorial--odL8-RG\Lib\site-packages\dash\dash.py:2519, in Dash.run(self, host, port, proxy, debug, hide_all_callbacks, jupyter_mode, jupyter_width, jupyter_height, jupyter_server_url, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_disable_version_check, dev_tools_prune_errors, **flask_run_options)
#    2516             extra_files.append(path)
#    2518 if jupyter_dash.active:
# -> 2519     jupyter_dash.run_app(
#    2520         self,
#    2521         mode=jupyter_mode,
#    2522         width=jupyter_width,
#    2523         height=jupyter_height,
#    2524         host=host,
#    2525         port=port,
#    2526         server_url=jupyter_server_url,
#    2527     )
#    2528 else:
#    2529     self.server.run(host=host, port=port, debug=debug, **flask_run_options)
#
# File ~\.virtualenvs\arxiv_tutorial--odL8-RG\Lib\site-packages\dash\_jupyter.py:474, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     472     display(HTML(msg))
#     473 else:
# --> 474     raise final_error
#
# File ~\.virtualenvs\arxiv_tutorial--odL8-RG\Lib\site-packages\dash\_jupyter.py:461, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     458         raise err
#     460 try:
# --> 461     wait_for_app()
#     463     if self.in_colab:
#     464         JupyterDash._display_in_colab(dashboard_url, port, mode, width, height)
#
# File ~\.virtualenvs\arxiv_tutorial--odL8-RG\Lib\site-packages\retrying.py:55, in retry.<locals>.wrap.<locals>.wrapped_f(*args, **kw)
#      53 @wraps(f)
#      54 def wrapped_f(*args, **kw):
# ---> 55     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#
# File ~\.virtualenvs\arxiv_tutorial--odL8-RG\Lib\site-packages\retrying.py:289, in Retrying.call(self, fn, *args, **kwargs)
#     286 if self.stop(attempt_number, delay_since_first_attempt_ms):
#     287     if not self._wrap_exception and attempt.has_exception:
#     288         # get() on an attempt with an exception should cause it to be raised, but raise just in case
# --> 289         raise attempt.get()
#     290     else:
#     291         raise RetryError(attempt)
#
# File ~\.virtualenvs\arxiv_tutorial--odL8-RG\Lib\site-packages\retrying.py:326, in Attempt.get(self, wrap_exception)
#     324     else:
#     325         exc_type, exc, tb = self.value
# --> 326         raise exc.with_traceback(tb)
#     327 else:
#     328     return self.value
#
# File ~\.virtualenvs\arxiv_tutorial--odL8-RG\Lib\site-packages\retrying.py:273, in Retrying.call(self, fn, *args, **kwargs)
#     270     self._before_attempts(attempt_number)
#     272 try:
# --> 273     attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     274 except Exception:
#     275     tb = sys.exc_info()
#
# File ~\.virtualenvs\arxiv_tutorial--odL8-RG\Lib\site-packages\dash\_jupyter.py:452, in JupyterDash.run_app.<locals>.wait_for_app()
#     450     if res != "Alive":
#     451         url = f"http://{host}:{port}"
# --> 452         raise OSError(
#     453             f"Address '{url}' already in use.\n"
#     454             "    Try passing a different port to run."
#     455         )
#     456 except requests.ConnectionError as err:
#     457     _get_error()
#
# OSError: Address 'http://127.0.0.1:8050' already in use.
#     Try passing a different port to run.

# %%
#fig.write_html("question1.0.2.html")
