# %% [markdown]
# #### Imports and Getting the top 100 cities

# %%
import requests
import pandas as pd
from time import sleep

# Reading location data about german cities
df = pd.read_csv(
    "DE.txt",
    sep='\t',
    header=None,
    names=[
        "geonameid", "name", "ascii", "lat", "lon", "feature_class", "feature_code",
        "country", "cc2", "admin1", "admin2", "admin3", "admin4",
        "population", "elevation", "dem", "timezone", "modification_date"
    ]
)
###########################
### CLEANING DATA FRAME ###
###########################

# Keep only populated places (feature_code starting with 'PPL')
df_cities = df[df["feature_code"].str.startswith("PPL")]
# Select relevant columns
df_cities = df_cities[["name", "lat", "lon", "population"]]
# Take the top 100 most populated cities, divided into segments
df_top_cities = df_cities.sort_values("population", ascending=False)
df_cities_1 = df_top_cities.iloc[0:20]
df_cities_2 = df_top_cities.iloc[20:40]
df_cities_3 = df_top_cities.iloc[40:60]
df_cities_4 = df_top_cities.iloc[60:80]
df_cities_5 = df_top_cities.iloc[80:100]

# %% [markdown]
# #### Function to get weather data from certain cities

# %%
# Returns the weather data the cities specified in the dataframe
def get_weather_data(cities):
    # Collection of weather data
    weather_data = []

    # Loop through each city
    for idx, row in cities.iterrows():
        city_name = row['name']
        lat = row['lat']
        lon = row['lon']
        population = row['population']
        
        # Get the peak temperature for each city from 2016-2025
        try:
            weather = requests.get(
                "https://archive-api.open-meteo.com/v1/archive",
                params = {
                    "latitude": lat,
                    "longitude": lon,
                    "start_date": "2016-01-01",
                    "end_date": "2025-12-31",
                    "daily": ["temperature_2m_max", "precipitation_sum"],
                    "timezone": "Europe/Berlin"
                }
            ).json()
            
            # Convert to DataFrame
            city_df = pd.DataFrame({
                "city": city_name,
                "population": population,
                "lat": weather['latitude'],
                "lon": weather['longitude'],
                "date": weather["daily"]["time"],
                "peak_temperature": weather["daily"]["temperature_2m_max"],
                "precipitation_mm": weather["daily"]["precipitation_sum"]
            })
            
            weather_data.append(city_df)
            # Help avoid rate limits
            sleep(1)
            print(f"Fetched weather for {city_name}")
        
        except Exception as e:
            print(f"Failed for {city_name}: {e}")
    return weather_data

# %% [markdown]
# Cities 1-20

# %%
weather_data_1 = get_weather_data(df_cities_1)
df = pd.concat(weather_data_1, ignore_index = True)
df.to_csv('Weather_Cities_1_20.csv', index = False)
# Out:
# Failed for Berlin: 'latitude'
# Failed for Hamburg: 'latitude'
# Failed for Munich: 'latitude'
# Failed for Koeln: 'latitude'
# Failed for Frankfurt am Main: 'latitude'
# Failed for Stuttgart: 'latitude'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 weather_data_1 = get_weather_data(df_cities_1)
#
# Cell In[10], line 15, in get_weather_data(cities)
#      13 # Get the peak temperature for each city from 2016-2025
#      14 try:
# ---> 15     weather = requests.get(
#      16         "https://archive-api.open-meteo.com/v1/archive",
#      17         params = {
#      18             "latitude": lat,
#      19             "longitude": lon,
#      20             "start_date": "2016-01-01",
#      21             "end_date": "2025-12-31",
#      22             "daily": ["temperature_2m_max", "precipitation_sum"],
#      23             "timezone": "Europe/Berlin"
#      24         }
#      25     ).json()
#      27     # Convert to DataFrame
#      28     city_df = pd.DataFrame({
#      29         "city": city_name,
#      30         "population": population,
#    (...)     35         "precipitation_mm": weather["daily"]["precipitation_sum"]
#      36     })
#
# File c:\Users\Anwender\.virtualenvs\DataScienceProject-7w5oTDQl\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\Anwender\.virtualenvs\DataScienceProject-7w5oTDQl\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Anwender\.virtualenvs\DataScienceProject-7w5oTDQl\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Anwender\.virtualenvs\DataScienceProject-7w5oTDQl\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Anwender\.virtualenvs\DataScienceProject-7w5oTDQl\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File c:\Users\Anwender\.virtualenvs\DataScienceProject-7w5oTDQl\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\Anwender\.virtualenvs\DataScienceProject-7w5oTDQl\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\Anwender\.virtualenvs\DataScienceProject-7w5oTDQl\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 # Force connect early to allow us to validate the connection.
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1096 if not conn.is_verified and not conn.proxy_is_verified:
#
# File c:\Users\Anwender\.virtualenvs\DataScienceProject-7w5oTDQl\Lib\site-packages\urllib3\connection.py:796, in HTTPSConnection.connect(self)
#     793     # Remove trailing '.' from fqdn hostnames to allow certificate validation
#     794     server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 796     sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     797         sock=sock,
#     798         cert_reqs=self.cert_reqs,
#     799         ssl_version=self.ssl_version,
#     800         ssl_minimum_version=self.ssl_minimum_version,
#     801         ssl_maximum_version=self.ssl_maximum_version,
#     802         ca_certs=self.ca_certs,
#     803         ca_cert_dir=self.ca_cert_dir,
#     804         ca_cert_data=self.ca_cert_data,
#     805         cert_file=self.cert_file,
#     806         key_file=self.key_file,
#     807         key_password=self.key_password,
#     808         server_hostname=server_hostname_rm_dot,
#     809         ssl_context=self.ssl_context,
#     810         tls_in_tls=tls_in_tls,
#     811         assert_hostname=self.assert_hostname,
#     812         assert_fingerprint=self.assert_fingerprint,
#     813     )
#     814     self.sock = sock_and_verified.socket
#     816 # If an error occurs during connection/handshake we may need to release
#     817 # our lock so another connection can probe the origin.
#
# File c:\Users\Anwender\.virtualenvs\DataScienceProject-7w5oTDQl\Lib\site-packages\urllib3\connection.py:975, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     972     if is_ipaddress(normalized):
#     973         server_hostname = normalized
# --> 975 ssl_sock = ssl_wrap_socket(
#     976     sock=sock,
#     977     keyfile=key_file,
#     978     certfile=cert_file,
#     979     key_password=key_password,
#     980     ca_certs=ca_certs,
#     981     ca_cert_dir=ca_cert_dir,
#     982     ca_cert_data=ca_cert_data,
#     983     server_hostname=server_hostname,
#     984     ssl_context=context,
#     985     tls_in_tls=tls_in_tls,
#     986 )
#     988 try:
#     989     if assert_fingerprint:
#
# File c:\Users\Anwender\.virtualenvs\DataScienceProject-7w5oTDQl\Lib\site-packages\urllib3\util\ssl_.py:461, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     459 if ca_certs or ca_cert_dir or ca_cert_data:
#     460     try:
# --> 461         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     462     except OSError as e:
#     463         raise SSLError(e) from e
#
# KeyboardInterrupt:

# %% [markdown]
# Cities 21-40

# %%
weather_data_2 = get_weather_data(df_cities_2)
df = pd.concat(weather_data_2, ignore_index = True)
df.to_csv('Weather_Cities_21_40.csv', index = False)
# Out:
# Fetched weather for Hamburg-Nord
# Fetched weather for Mannheim
# Fetched weather for Hamburg-Mitte
# Fetched weather for Marienthal
# Fetched weather for Karlsruhe
# Fetched weather for Wiesbaden
# Fetched weather for Muenster
# Fetched weather for Gelsenkirchen
# Fetched weather for Eimsbuettel
# Fetched weather for Aachen
# Fetched weather for Moenchengladbach
# Fetched weather for Augsburg
# Fetched weather for Altona
# Fetched weather for Chemnitz
# Fetched weather for Kiel
# Fetched weather for Braunschweig
# Fetched weather for Krefeld
# Fetched weather for Halle (Saale)
# Fetched weather for Magdeburg
# Fetched weather for Neue Neustadt

# %% [markdown]
# Cities 41-60

# %%
weather_data_3 = get_weather_data(df_cities_3)
df = pd.concat(weather_data_3, ignore_index = True)
df.to_csv('Weather_Cities_41_60.csv', index = False)
# Out:
# Fetched weather for Oberhausen
# Fetched weather for Mainz
# Fetched weather for Freiburg
# Fetched weather for Erfurt
# Fetched weather for Luebeck
# Fetched weather for Hagen
# Fetched weather for Rostock
# Fetched weather for Kassel
# Fetched weather for Potsdam
# Failed for Saarbruecken: 'latitude'
# Failed for Hamm: 'latitude'
# Failed for Herne: 'latitude'
# Failed for Muelheim: 'latitude'
# Failed for Harburg: 'latitude'
# Failed for Osnabrueck: 'latitude'
# Failed for Neukoelln: 'latitude'
# Failed for Solingen: 'latitude'
# Failed for Ludwigshafen am Rhein: 'latitude'
# Failed for Leverkusen: 'latitude'
# Failed for Oldenburg: 'latitude'

# %% [markdown]
# Cities 61-80

# %%
weather_data_4 = get_weather_data(df_cities_4)
df = pd.concat(weather_data_4, ignore_index = True)
df.to_csv('Weather_Cities_61_80.csv', index = False)
# Out:
# Fetched weather for Kreuzberg
# Fetched weather for Neuss
# Fetched weather for Prenzlauer Berg Bezirk
# Fetched weather for Heidelberg
# Fetched weather for Paderborn
# Fetched weather for Darmstadt
# Fetched weather for Wuerzburg
# Fetched weather for Charlottenburg
# Fetched weather for Regensburg
# Fetched weather for Wolfsburg
# Fetched weather for Schoeneberg
# Fetched weather for Recklinghausen
# Failed for Goettingen: 'latitude'
# Failed for Heilbronn: 'latitude'
# Failed for Ingolstadt: 'latitude'
# Failed for Ulm: 'latitude'
# Failed for Bottrop: 'latitude'
# Failed for Bergedorf: 'latitude'
# Failed for Pforzheim: 'latitude'
# Failed for Offenbach: 'latitude'

# %% [markdown]
# Cities 81-100

# %%
weather_data_5 = get_weather_data(df_cities_5)
df = pd.concat(weather_data_5, ignore_index = True)
df.to_csv('Weather_Cities_81_100.csv', index = False)
# Out:
# Fetched weather for Friedrichshain Bezirk
# Fetched weather for Remscheid
# Fetched weather for Bremerhaven
# Fetched weather for Nippes
# Fetched weather for Porz am Rhein
# Fetched weather for Reutlingen
# Fetched weather for Furth
# Fetched weather for Marzahn
# Fetched weather for Rodenkirchen
# Fetched weather for Koblenz
# Fetched weather for Siegen
# Fetched weather for Bergisch Gladbach
# Fetched weather for Jena
# Fetched weather for Gera
# Fetched weather for Salzgitter
# Fetched weather for Moers
# Fetched weather for Hildesheim
# Fetched weather for Erlangen
# Fetched weather for Mitte
# Fetched weather for Wilmersdorf

# %% [markdown]
# #### Combine all the data into .csv

# %%
file1 = pd.read_csv('Weather_Cities_1_20.csv')
file2 = pd.read_csv('Weather_Cities_21_40.csv')
file3 = pd.read_csv('Weather_Cities_41_60.csv')
file4 = pd.read_csv('Weather_Cities_61_80.csv')
file5 = pd.read_csv('Weather_Cities_81_100.csv')

combined = pd.concat([file1, file2, file3, file4, file5], ignore_index=True)
combined.to_csv('Weather_Cities_all.csv', index=False)

# %% [markdown]
# #### Error handling for too many requests

# %%
weather = requests.get(
                "https://archive-api.open-meteo.com/v1/archive",
                params = {
                    "latitude": 53.1,
                    "longitude": 45.2,
                    "start_date": "2016-01-01",
                    "end_date": "2025-12-31",
                    "daily": ["temperature_2m_max","precipitation_sum"],
                    "timezone": "Europe/Berlin"
                }
)
weather.json()
# Out:
# {'reason': 'Hourly API request limit exceeded. Please try again in the next hour.',
#  'error': True}
